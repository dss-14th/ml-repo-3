# %% [markdown]
# <h1>EDA_data_association<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#전체-투표참여량" data-toc-modified-id="전체-투표참여량-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>전체 투표참여량</a></span></li><li><span><a href="#Feature별-투표-참여량-&amp;-참여율" data-toc-modified-id="Feature별-투표-참여량-&amp;-참여율-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Feature별 투표 참여량 &amp; 참여율</a></span><ul class="toc-item"><li><span><a href="#QA" data-toc-modified-id="QA-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>QA</a></span></li><li><span><a href="#QI" data-toc-modified-id="QI-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>QI</a></span></li><li><span><a href="#QE" data-toc-modified-id="QE-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>QE</a></span></li><li><span><a href="#score" data-toc-modified-id="score-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>score</a></span></li><li><span><a href="#TYP" data-toc-modified-id="TYP-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>TYP</a></span></li><li><span><a href="#VCL" data-toc-modified-id="VCL-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>VCL</a></span></li><li><span><a href="#education" data-toc-modified-id="education-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>education</a></span></li><li><span><a href="#hometown" data-toc-modified-id="hometown-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>hometown</a></span></li><li><span><a href="#gender" data-toc-modified-id="gender-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>gender</a></span></li><li><span><a href="#first-language" data-toc-modified-id="first-language-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>first language</a></span></li><li><span><a href="#age" data-toc-modified-id="age-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>age</a></span></li><li><span><a href="#hand" data-toc-modified-id="hand-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>hand</a></span></li><li><span><a href="#religion" data-toc-modified-id="religion-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>religion</a></span></li><li><span><a href="#orientation" data-toc-modified-id="orientation-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>orientation</a></span></li><li><span><a href="#race" data-toc-modified-id="race-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>race</a></span></li><li><span><a href="#married" data-toc-modified-id="married-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>married</a></span></li><li><span><a href="#familysize" data-toc-modified-id="familysize-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>familysize</a></span></li><li><span><a href="#major" data-toc-modified-id="major-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>major</a></span></li><li><span><a href="#country" data-toc-modified-id="country-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>country</a></span></li><li><span><a href="#screen-size" data-toc-modified-id="screen-size-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>screen size</a></span></li><li><span><a href="#duration" data-toc-modified-id="duration-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>duration</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## 전체 투표참여량

# %% [markdown]
# - raw dataset의 투표참여량

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x=df['voted']);

# %% [markdown]
# - 선거가능연령 dataset의 투표참여량

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x=df['voted']);

# %% [markdown]
# ## Feature별 투표 참여량 & 참여율

# %% [markdown]
# ### QA

# %% [markdown]
# - MACH-IV 각 질문지 답변별 투표참여량

# %%
figure, ((ax1,ax2,ax3,ax4,ax5), (ax6,ax7,ax8,ax9,ax10), (ax11, ax12, ax13, ax14, ax15), (ax16, ax17, ax18, ax19, ax20)) = plt.subplots(nrows=4, ncols=5)
figure.set_size_inches(20,16)

for n, c in enumerate(pos_col):
    ax = globals()["ax" + '{}'.format(n+1)]    
    plt_ = sns.histplot(df, x=c, hue='voted', binwidth=0.5, ax=ax)
    plt_.set(ylabel="", ylim=(0, 22000))

for n, c in enumerate(neg_col):
    ax = globals()["ax" + '{}'.format(n+11)]  
    plt_= sns.histplot(df, x=c, hue='voted', binwidth=0.5, ax=ax)
    plt_.set(ylabel="", ylim=(0, 22000))

# %% [markdown]
# ### QI

# %% [markdown]
# - MACH-IV 각 질문지 위치별 투표참여량

# %%
figure, ((ax1,ax2,ax3,ax4,ax5), (ax6,ax7,ax8,ax9,ax10), (ax11, ax12, ax13, ax14, ax15), (ax16, ax17, ax18, ax19, ax20)) = plt.subplots(nrows=4, ncols=5)
figure.set_size_inches(20,16)

for n, c in enumerate(i_col):
    ax = globals()["ax" + '{}'.format(n+1)]    
    plt_ = sns.histplot(df, x=c, hue='voted', binwidth=0.5, ax=ax, legend=False)
    plt_.set(ylabel="", ylim=(0, 1750))

# %% [markdown]
# ### QE

# %% [markdown]
# - MACH-IV 각 질문지별 답변시간 분포

# %%
plt.figure(figsize=(20, 12))
plt.suptitle('duration time of each question')

plt.subplot(331)
df_QE.describe().loc['mean'].plot(kind='line')
plt.gca().set_title('mean')

plt.subplot(332)
df_QE.describe().loc['min'].plot(kind='line')
plt.gca().set_title('min')

plt.subplot(333)
df_QE.describe().loc['25%'].plot(kind='line')
plt.gca().set_title('25%')

plt.subplot(334)
df_QE.describe().loc['50%'].plot(kind='line')
plt.gca().set_title('50%')

plt.subplot(335)
df_QE.describe().loc['75%'].plot(kind='line')
plt.gca().set_title('75%')

plt.subplot(336)
df_QE.describe().loc['max'].plot(kind='line')
plt.gca().set_title('max')
# Out:
# Text(0.5, 1.0, 'max')

# %% [markdown]
# ### score
# - MACH-IV 답변 통합 점수

# %%
plt.figure(figsize=(10, 4))
sns.histplot(df, x='score', hue='voted')

# %% [markdown]
# ### TYP
# - 성격 일치 수준별 투표참여량

# %%
figure, ((ax1,ax2,ax3,ax4,ax5), (ax6,ax7,ax8,ax9,ax10)) = plt.subplots(nrows=2, ncols=5)
figure.set_size_inches(20,10)

for n, c in enumerate(typ_col):
    ax = globals()["ax" + '{}'.format(n+1)]
    
    plt_ = sns.histplot(df, x=c, hue='voted', binwidth=2, ax=ax)
    plt_.set(ylabel="", ylim=(0, 25000))

# %% [markdown]
# ### VCL
# - 단어별 인지 여부에 따른 투표참여량

# %%
label = ["know", "n_know"]
index=np.arange(len(label))

plt.figure(figsize=(20, 20))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plot1 = sns.histplot(x=df_vcl[df_vcl.columns[i]], hue=df_vcl['voted'])
    plot1.set(ylabel="", ylim=(0, 33000))
    plt.xticks(index, label)
plt.show()

# %% [markdown]
# ### education
# - 교육 수준에 따른 투표참여량

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['education'], hue=df['voted']);

# %% [markdown]
# ### hometown
# - 출신지역에 따른 투표참여량

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df['urban'], hue=df['voted']);

# %% [markdown]
# ### gender
# - 성별에 따른 투표참여량

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df['gender'], hue=df['voted']);

# %% [markdown]
# ### first language
# - 모국어 영어 여부에 따른 투표참여량

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df['engnat'], hue=df['voted']);

# %% [markdown]
# ### age
# - 나이별 투표참여량

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x=df['age'], hue=df['voted']);

# %% [markdown]
# ### hand
# - 주 사용손에 따른 투표참여량

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df['hand'], hue=df['voted']);

# %% [markdown]
# ### religion
# - 종교에 따른 투표참여량

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x=df['religion'], hue=df['voted']);

# %% [markdown]
# ### orientation
# - 성정체성에 다른 투표참여량

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df['orientation'], hue=df['voted']);

# %% [markdown]
# ### race
# - 인종에 다른 투표참여량

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['race'], hue=df['voted']);

# %% [markdown]
# ### married
# - 결혼여부에 따른 투표참여량

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df['married'], hue=df['voted']);

# %% [markdown]
# ### familysize
# - 가족구성원수에 따른 투표참여량

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x=df['familysize'], hue=df['voted'])
plt.legend(loc='upper center');

# %% [markdown]
# ### major
# - 전공 별 테스트 참여자 수

# %%
majors = df['major'].str.lower()
majors = majors.str.strip()
majors.value_counts()
# Out:
# psychology                              3367
# business                                1988
# engineering                             1734
# english                                 1501
# computer science                        1435
#                                         ...
# business & management and psychology       1
# lái tàu                                    1
# education and music                        1
# economics politics and law                 1
# òõêõ                                       1
# Name: major, Length: 6380, dtype: int64

# %% [markdown]
# ### country
# - 소속 서버 지역별 투표참여량

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['country'], hue=df['voted'])
plt.legend(loc='upper center');

# %% [markdown]
# - 참여자 100명 이상 소속 서버 지역별 투표참여량

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x=df_cntr_100['country'], hue=df_cntr_100['voted']);

# %% [markdown]
# ### screen size
# - 참여자 사용 스크린 사이즈별 투표참여량

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['screenw'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['screenh'], hue=df['voted'])
plt.legend(loc='upper center');

# %% [markdown]
# ### duration
# - 테스트 참여 소요시간별 투표참여량

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['introelapse'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['testelapse'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['surveyelapse'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
import EDAGraph as eda

# %%
test = eda.EDA_Graph("../MACH_data/raw_data_for_EDA.csv")
