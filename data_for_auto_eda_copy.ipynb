# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#sweetviz용-데이터-전처리" data-toc-modified-id="sweetviz용-데이터-전처리-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>sweetviz용 데이터 전처리</a></span><ul class="toc-item"><li><span><a href="#전체-데이터-불러오기" data-toc-modified-id="전체-데이터-불러오기-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>전체 데이터 불러오기</a></span></li><li><span><a href="#컬럼명-수정" data-toc-modified-id="컬럼명-수정-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>컬럼명 수정</a></span></li><li><span><a href="#컬럼-추가" data-toc-modified-id="컬럼-추가-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>컬럼 추가</a></span><ul class="toc-item"><li><span><a href="#score-컬럼" data-toc-modified-id="score-컬럼-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>score 컬럼</a></span></li><li><span><a href="#V,-T,-M-컬럼-추가" data-toc-modified-id="V,-T,-M-컬럼-추가-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>V, T, M 컬럼 추가</a></span></li></ul></li><li><span><a href="#데이터-변환" data-toc-modified-id="데이터-변환-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>데이터 변환</a></span><ul class="toc-item"><li><span><a href="#숫자형-데이터-=>-텍스트-데이터" data-toc-modified-id="숫자형-데이터-=>-텍스트-데이터-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>숫자형 데이터 =&gt; 텍스트 데이터</a></span></li><li><span><a href="#시간-데이터-단위변환" data-toc-modified-id="시간-데이터-단위변환-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>시간 데이터 단위변환</a></span></li></ul></li><li><span><a href="#이상치-확인-&amp;-처리" data-toc-modified-id="이상치-확인-&amp;-처리-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>이상치 확인 &amp; 처리</a></span><ul class="toc-item"><li><span><a href="#major-컬럼-drop" data-toc-modified-id="major-컬럼-drop-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>major 컬럼 drop</a></span></li><li><span><a href="#컬럼별-'0'-데이터-확인" data-toc-modified-id="컬럼별-'0'-데이터-확인-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>컬럼별 '0' 데이터 확인</a></span><ul class="toc-item"><li><span><a href="#역추적용-csv-생성" data-toc-modified-id="역추적용-csv-생성-1.5.2.1"><span class="toc-item-num">1.5.2.1&nbsp;&nbsp;</span>역추적용 csv 생성</a></span></li></ul></li><li><span><a href="#age-컬럼-이상치-->-미완성" data-toc-modified-id="age-컬럼-이상치-->-미완성-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>age 컬럼 이상치 -&gt; <code>미완성</code></a></span></li><li><span><a href="#familysize-(가족단위)-컬럼-->-미완성" data-toc-modified-id="familysize-(가족단위)-컬럼-->-미완성-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>familysize (가족단위) 컬럼 -&gt; <code>미완성</code></a></span></li><li><span><a href="#컬럼별-null-데이터-확인-후-drop" data-toc-modified-id="컬럼별-null-데이터-확인-후-drop-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>컬럼별 null 데이터 확인 후 drop</a></span></li></ul></li><li><span><a href="#EDA용-csv-생성" data-toc-modified-id="EDA용-csv-생성-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>EDA용 csv 생성</a></span></li></ul></li><li><span><a href="#sweetviz-리포트-생성" data-toc-modified-id="sweetviz-리포트-생성-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>sweetviz 리포트 생성</a></span><ul class="toc-item"><li><span><a href="#리포트-확인-후-컬럼-재확인-->-확인!!!" data-toc-modified-id="리포트-확인-후-컬럼-재확인-->-확인!!!-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>리포트 확인 후 컬럼 재확인 -&gt; <code>확인!!!</code></a></span></li><li><span><a href="#compare_intra-사용" data-toc-modified-id="compare_intra-사용-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>compare_intra 사용</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## sweetviz용 데이터 전처리

# %% [markdown]
# ### 전체 데이터 불러오기

# %%
df = pd.read_csv('./MACH_data/data.csv', delimiter='\t')
df
# Out:
#        Q1A   Q1I      Q1E  Q2A   Q2I      Q2E  Q3A   Q3I      Q3E  Q4A  ...  \
# 0      3.0   6.0  21017.0  3.0   7.0  18600.0  5.0  20.0  14957.0  2.0  ...
# 1      5.0  17.0   3818.0  5.0   9.0   7850.0  1.0  16.0   5902.0  3.0  ...
# 2      5.0  16.0   4186.0  5.0  12.0   2900.0  1.0   2.0   7160.0  1.0  ...
# 3      2.0  12.0   9373.0  4.0   1.0  10171.0  2.0   7.0  10117.0  1.0  ...
# 4      5.0  13.0   9465.0  5.0   7.0   5284.0  2.0  19.0   8872.0  1.0  ...
# ...    ...   ...      ...  ...   ...      ...  ...   ...      ...  ...  ...
# 73484  2.0  17.0   9925.0  1.0   6.0  14218.0  2.0  16.0  25499.0  4.0  ...
# 73485  5.0   9.0   5816.0  5.0   4.0   4368.0  1.0  15.0   7246.0  1.0  ...
# 73486  2.0  17.0   5353.0  1.0  18.0   6846.0  1.0   9.0   4920.0  1.0  ...
# 73487  4.0  15.0   7974.0  3.0   9.0   7901.0  5.0  17.0   8647.0  3.0  ...
# 73488  3.0  12.0   7567.0  1.0  10.0   5766.0  5.0  13.0  37103.0  1.0  ...
#
#        screenw  screenh  hand  religion  orientation  race  voted  married  \
# 0       1440.0    900.0     1         7            1    30      1        2
# 1       1536.0    864.0     1         1            1    60      2        1
# 2        375.0    667.0     1         2            2    10      2        1
# 3       1280.0    720.0     1         6            1    60      1        3
# 4        360.0    640.0     1         4            3    60      1        1
# ...        ...      ...   ...       ...          ...   ...    ...      ...
# 73484   2048.0   1080.0     1        12            1    10      2        2
# 73485   1440.0    900.0     1         2            3    60      2        1
# 73486   1280.0   1024.0     1         1            1    60      2        1
# 73487    414.0    736.0     1         3            1    10      1        1
# 73488   1366.0    768.0     1         4            1    70      2        1
#
#        familysize                    major
# 0               5               Marketing
# 1               2              mathematics
# 2               2                Chemistry
# 3               2  international relations
# 4               2               Management
# ...           ...                      ...
# 73484           1                 business
# 73485           2                sociology
# 73486           3                      NaN
# 73487           4                 Business
# 73488           4                      NaN
#
# [73489 rows x 105 columns]

# %% [markdown]
# ### 컬럼명 수정

# %% [markdown]
# > 컬럼명에 컬럼 정보 추가하여 수정
# > - 직관적 EDA 수행 목적

# %%
df.rename(columns = {"Q1A" : "Q1_TP_notell_2u", "Q2A" : "Q2_TP_ppl_nd_dangun", "Q3A" : "Q3_TN_do_moral", "Q4A" : "Q4_VN_ppl_good", "Q5A" : "Q5_VP_ppl_bad", "Q6A" : "Q6_TN_hnsty_best", "Q7A" : "Q7_TN_lying_bad", "Q8A" : "Q8_VP_ppl_lazy", "Q9A" : "Q9_MN_humble_hnst", "Q10A" : "Q10_TN_hnstly_ask", "Q11A" : "Q11_VN_leader_clean", "Q12A" : "Q12_TP_trust_trouble", "Q13A" : "Q13_VP_ppl_criminal", "Q14A" : "Q14_VN_ppl_brave", "Q15A" : "Q15_TP_abu_good", "Q16A" : "Q16_TN_ppl_good", "Q17A" : "Q17_VN_ppl_notbad", "Q18A" : "Q18_VP_komsu_better", "Q19A" : "Q19_MP_anrocksa_ok", "Q20A" : "Q20_VP_money_good",
                     "Q1E" : "Q1E_notell_2u", "Q2E" : "Q2E_ppl_nd_dangun", "Q3E" : "Q3E_do_moral", "Q4E" : "Q4E_ppl_good", "Q5E" : "Q5E_ppl_bad", "Q6E" : "Q6E_hnsty_best", "Q7E" : "Q7E_lying_bad", "Q8E" : "Q8E_ppl_lazy", "Q9E" : "Q9E_humble_hnst", "Q10E" : "Q10E_hnstly_ask", "Q11E" : "Q11E_leader_clean", "Q12E" : "Q12E_trust_trouble", "Q13E" : "Q13E_ppl_criminal", "Q14E" : "Q14E_ppl_brave", "Q15E" : "Q15E_abu_good", "Q16E" : "Q16E_ppl_good", "Q17E" : "Q17E_ppl_notbad", "Q18E" : "Q18E_komsu_better", "Q19E" : "Q19E_anrocksa_ok", "Q20E" : "Q20E_money_good",
                     "TIPI1":"TYP_out", "TIPI2":"TYP_fight", "TIPI3":"TYP_depnd", "TIPI4":"TYP_anx", "TIPI5":"TYP_try", "TIPI6":"TYP_quiet", "TIPI7":"TYP_warm", "TIPI8":"TYP_disorg", "TIPI9":"TYP_calm", "TIPI10":"TYP_stable",
                     "VCL6" : "VCL6_F", "VCL9" : "VCL9_F", "VCL12" : "VCL12_F"
                    }, inplace=True)

# %%
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0        21017.0                  3.0   7.0
# 1                  5.0  17.0         3818.0                  5.0   9.0
# 2                  5.0  16.0         4186.0                  5.0  12.0
# 3                  2.0  12.0         9373.0                  4.0   1.0
# 4                  5.0  13.0         9465.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 73484              2.0  17.0         9925.0                  1.0   6.0
# 73485              5.0   9.0         5816.0                  5.0   4.0
# 73486              2.0  17.0         5353.0                  1.0  18.0
# 73487              4.0  15.0         7974.0                  3.0   9.0
# 73488              3.0  12.0         7567.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 0                18600.0             5.0  20.0       14957.0             2.0
# 1                 7850.0             1.0  16.0        5902.0             3.0
# 2                 2900.0             1.0   2.0        7160.0             1.0
# 3                10171.0             2.0   7.0       10117.0             1.0
# 4                 5284.0             2.0  19.0        8872.0             1.0
# ...                  ...             ...   ...           ...             ...
# 73484            14218.0             2.0  16.0       25499.0             4.0
# 73485             4368.0             1.0  15.0        7246.0             1.0
# 73486             6846.0             1.0   9.0        4920.0             1.0
# 73487             7901.0             5.0  17.0        8647.0             3.0
# 73488             5766.0             5.0  13.0       37103.0             1.0
#
#        ...  screenw  screenh  hand  religion  orientation  race  voted  \
# 0      ...   1440.0    900.0     1         7            1    30      1
# 1      ...   1536.0    864.0     1         1            1    60      2
# 2      ...    375.0    667.0     1         2            2    10      2
# 3      ...   1280.0    720.0     1         6            1    60      1
# 4      ...    360.0    640.0     1         4            3    60      1
# ...    ...      ...      ...   ...       ...          ...   ...    ...
# 73484  ...   2048.0   1080.0     1        12            1    10      2
# 73485  ...   1440.0    900.0     1         2            3    60      2
# 73486  ...   1280.0   1024.0     1         1            1    60      2
# 73487  ...    414.0    736.0     1         3            1    10      1
# 73488  ...   1366.0    768.0     1         4            1    70      2
#
#        married  familysize                    major
# 0            2           5               Marketing
# 1            1           2              mathematics
# 2            1           2                Chemistry
# 3            3           2  international relations
# 4            1           2               Management
# ...        ...         ...                      ...
# 73484        2           1                 business
# 73485        1           2                sociology
# 73486        1           3                      NaN
# 73487        1           4                 Business
# 73488        1           4                      NaN
#
# [73489 rows x 105 columns]

# %% [markdown]
# ### 컬럼 추가

# %%
col_list = list(df.columns)

# %% [markdown]
# #### score 컬럼

# %% [markdown]
# > 테스트 참여자의 마키아벨리즘에 대한 수용 수준 점수화
# - 점수화 소스 데이터
#     - 마키아벨리즘 test 답변 점수
#     - 1점(Disagree) ~ 5점(Agree)
# >
# >
# - 점수화 공식
#     - ```수용적 경향 질문지 답변 점수의 합```  +  ```불수용적 경향 질문지 답변 점수의 역변환 값 (6-점수) ```

# %%
pos_col = []
neg_col = []

for col in col_list:
    if "P" in col and "Y" not in col:
        pos_col.append(col)
    if "N" in col:
        neg_col.append(col)
        
print(pos_col, '\n', '\n', neg_col)
# Out:
# ['Q1_TP_notell_2u', 'Q2_TP_ppl_nd_dangun', 'Q5_VP_ppl_bad', 'Q8_VP_ppl_lazy', 'Q12_TP_trust_trouble', 'Q13_VP_ppl_criminal', 'Q15_TP_abu_good', 'Q18_VP_komsu_better', 'Q19_MP_anrocksa_ok', 'Q20_VP_money_good']
#
#  ['Q3_TN_do_moral', 'Q4_VN_ppl_good', 'Q6_TN_hnsty_best', 'Q7_TN_lying_bad', 'Q9_MN_humble_hnst', 'Q10_TN_hnstly_ask', 'Q11_VN_leader_clean', 'Q14_VN_ppl_brave', 'Q16_TN_ppl_good', 'Q17_VN_ppl_notbad']

# %%
df["score"] = df[pos_col].sum(axis=1) + df[neg_col].apply(lambda x: 6 -x).sum(axis=1)
df["score"]
# Out:
# 0        75.0
# 1        91.0
# 2        98.0
# 3        78.0
# 4        85.0
#          ...
# 73484    59.0
# 73485    90.0
# 73486    69.0
# 73487    53.0
# 73488    64.0
# Name: score, Length: 73489, dtype: float64

# %%
df["score"].describe()
# Out:
# count    73489.000000
# mean        67.681531
# std         15.783480
# min          0.000000
# 25%         56.000000
# 50%         68.000000
# 75%         80.000000
# max        100.000000
# Name: score, dtype: float64

# %%
## 결측치 포착..
df[df["score"]==0.0]
# Out:
#        Q1_TP_notell_2u  Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun  Q2I  \
# 26286              NaN  NaN            NaN                  NaN  NaN
# 31072              NaN  NaN            NaN                  NaN  NaN
# 33399              NaN  NaN            NaN                  NaN  NaN
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral  Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 26286                NaN             NaN  NaN           NaN             NaN
# 31072                NaN             NaN  NaN           NaN             NaN
# 33399                NaN             NaN  NaN           NaN             NaN
#
#        ...  screenh  hand  religion  orientation  race  voted  married  \
# 26286  ...    640.0     1         2            1    20      2        1
# 31072  ...    900.0     1         6            1    30      1        2
# 33399  ...    768.0     1         4            1    60      2        2
#
#        familysize                   major  score
# 26286           2                     NaN    0.0
# 31072           3            math/science    0.0
# 33399           5  Electronic Engineering    0.0
#
# [3 rows x 106 columns]

# %% [markdown]
# #### V, T, M 컬럼 추가

# %%
a = 6 - df.loc[:,neg_col]
b = df.loc[:,pos_col]
c = pd.concat([a,b], axis=1)
d=list(c.columns)
d
# Out:
# ['Q3_TN_do_moral',
#  'Q4_VN_ppl_good',
#  'Q6_TN_hnsty_best',
#  'Q7_TN_lying_bad',
#  'Q9_MN_humble_hnst',
#  'Q10_TN_hnstly_ask',
#  'Q11_VN_leader_clean',
#  'Q14_VN_ppl_brave',
#  'Q16_TN_ppl_good',
#  'Q17_VN_ppl_notbad',
#  'Q1_TP_notell_2u',
#  'Q2_TP_ppl_nd_dangun',
#  'Q5_VP_ppl_bad',
#  'Q8_VP_ppl_lazy',
#  'Q12_TP_trust_trouble',
#  'Q13_VP_ppl_criminal',
#  'Q15_TP_abu_good',
#  'Q18_VP_komsu_better',
#  'Q19_MP_anrocksa_ok',
#  'Q20_VP_money_good']

# %%
v_score = []
t_score = []
m_score = []

for col in d:
    if "T" in col:
        t_score.append(col)
    if "M" in col:
        m_score.append(col)
    if "V" in col:
        v_score.append(col)
        
print(v_score, t_score, m_score)
# Out:
# ['Q4_VN_ppl_good', 'Q11_VN_leader_clean', 'Q14_VN_ppl_brave', 'Q17_VN_ppl_notbad', 'Q5_VP_ppl_bad', 'Q8_VP_ppl_lazy', 'Q13_VP_ppl_criminal', 'Q18_VP_komsu_better', 'Q20_VP_money_good'] ['Q3_TN_do_moral', 'Q6_TN_hnsty_best', 'Q7_TN_lying_bad', 'Q10_TN_hnstly_ask', 'Q16_TN_ppl_good', 'Q1_TP_notell_2u', 'Q2_TP_ppl_nd_dangun', 'Q12_TP_trust_trouble', 'Q15_TP_abu_good'] ['Q9_MN_humble_hnst', 'Q19_MP_anrocksa_ok']

# %%
df["v_score"] = c.loc[:,v_score].sum(axis=1)

# %%
df["t_score"] = c.loc[:,t_score].sum(axis=1)

# %%
df["m_score"] = c.loc[:,m_score].sum(axis=1)

# %%
df["score"]
# Out:
# 0        75.0
# 1        91.0
# 2        98.0
# 3        78.0
# 4        85.0
#          ...
# 73484    59.0
# 73485    90.0
# 73486    69.0
# 73487    53.0
# 73488    64.0
# Name: score, Length: 73489, dtype: float64

# %%
df.loc[:,("v_score", "t_score", "m_score")].sum(axis=1)
# Out:
# 0        75.0
# 1        91.0
# 2        98.0
# 3        78.0
# 4        85.0
#          ...
# 73484    59.0
# 73485    90.0
# 73486    69.0
# 73487    53.0
# 73488    64.0
# Length: 73489, dtype: float64

# %% [markdown]
# ### 데이터 변환

# %%
vcl_col = []
sec_col = []

for col in col_list:
    if "VCL" in col:
        vcl_col.append(col)
    if "E" in col:
        sec_col.append(col)
print(vcl_col, '\n', '\n', sec_col)
# Out:
# ['VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6_F', 'VCL7', 'VCL8', 'VCL9_F', 'VCL10', 'VCL11', 'VCL12_F', 'VCL13', 'VCL14', 'VCL15', 'VCL16']
#
#  ['Q1E_notell_2u', 'Q2E_ppl_nd_dangun', 'Q3E_do_moral', 'Q4E_ppl_good', 'Q5E_ppl_bad', 'Q6E_hnsty_best', 'Q7E_lying_bad', 'Q8E_ppl_lazy', 'Q9E_humble_hnst', 'Q10E_hnstly_ask', 'Q11E_leader_clean', 'Q12E_trust_trouble', 'Q13E_ppl_criminal', 'Q14E_ppl_brave', 'Q15E_abu_good', 'Q16E_ppl_good', 'Q17E_ppl_notbad', 'Q18E_komsu_better', 'Q19E_anrocksa_ok', 'Q20E_money_good']

# %% [markdown]
# #### 숫자형 데이터 => 텍스트 데이터

# %% [markdown]
# > 숫자로 라벨링된 범주형 데이터를 텍스트 데이터로 변경
# > - 직관적 EDA 수행 목적

# %%
df[vcl_col] = df[vcl_col].applymap(lambda x: str(x).replace("1", "know") if x==1 else str(x).replace("0", "n_know"))

# %%
df[vcl_col].head()
# Out:
#    VCL1    VCL2    VCL3  VCL4  VCL5  VCL6_F    VCL7    VCL8  VCL9_F VCL10  \
# 0  know    know  n_know  know  know  n_know  n_know    know  n_know  know
# 1  know    know    know  know  know  n_know  n_know    know  n_know  know
# 2  know    know    know  know  know    know  n_know    know    know  know
# 3  know    know    know  know  know  n_know  n_know    know  n_know  know
# 4  know  n_know  n_know  know  know  n_know  n_know  n_know  n_know  know
#
#     VCL11 VCL12_F   VCL13   VCL14 VCL15 VCL16
# 0    know    know    know    know  know  know
# 1  n_know  n_know    know    know  know  know
# 2    know    know    know    know  know  know
# 3  n_know    know  n_know    know  know  know
# 4  n_know  n_know  n_know  n_know  know  know

# %%
def tran_cate(df, cate, x, y):
    df[cate] = df[cate].astype('str').replace(x, y)
    return df[cate]

# %%
cates = {
    'education' : ['Less than high school','High school','University degree','Graduate degree'],
    'urban' : ['Rural','Suburban','Urban'],
    'gender' : ['Male','Female','Other'],
    'engnat' : ['Yes','No'],
    'hand' : ['Right','Left','Both'],
    'religion' : ['Agnostic','Atheist','Buddhist','Christian(Catholic)','Christian(Mormon)','Christian(Protestant)','Christian(othrer)','Hindu','Jewish','Muslim','Sikh','Other'],
    'orientation' : ['Heterosexual','Bisexual','Homosexual','Asexual','Other'],
    'race' : ['Asian','Arab','Black','Indigenous Australian','Native American','White','Other'],
    'voted' : ['Yes','No'],
    'married' : ['Never married','Currently married','Previously married'],
}

# %%
for x in list(cates.keys()):
    for idx, y in enumerate(cates[x]):
        if x == 'race':
            tran_cate(df, x, "{}".format((idx+1)*10) ,y)
        else:    
            tran_cate(df, x, "{}".format(idx+1) ,y)

# %%
df.head()
# Out:
#    Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0              3.0   6.0        21017.0                  3.0   7.0
# 1              5.0  17.0         3818.0                  5.0   9.0
# 2              5.0  16.0         4186.0                  5.0  12.0
# 3              2.0  12.0         9373.0                  4.0   1.0
# 4              5.0  13.0         9465.0                  5.0   7.0
#
#    Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  ...  \
# 0            18600.0             5.0  20.0       14957.0             2.0  ...
# 1             7850.0             1.0  16.0        5902.0             3.0  ...
# 2             2900.0             1.0   2.0        7160.0             1.0  ...
# 3            10171.0             2.0   7.0       10117.0             1.0  ...
# 4             5284.0             2.0  19.0        8872.0             1.0  ...
#
#    screenh   hand               religion   orientation   race  voted  \
# 0    900.0  Right      Christian(othrer)  Heterosexual  Black    Yes
# 1    864.0  Right               Agnostic  Heterosexual  White     No
# 2    667.0  Right                Atheist      Bisexual  Asian     No
# 3    720.0  Right  Christian(Protestant)  Heterosexual  White    Yes
# 4    640.0  Right    Christian(Catholic)    Homosexual  White    Yes
#
#               married  familysize  major  score
# 0   Currently married           5   True   75.0
# 1       Never married           2   True   91.0
# 2       Never married           2   True   98.0
# 3  Previously married           2   True   78.0
# 4       Never married           2   True   85.0
#
# [5 rows x 106 columns]

# %% [markdown]
# #### 시간 데이터 단위변환

# %% [markdown]
# > 답변 시간 데이터를 밀리초 => 초단위로 환산

# %%
sec_col = []

for col in col_list:
    if "E" in col:
        sec_col.append(col)
sec_col
# Out:
# ['Q1E_notell_2u',
#  'Q2E_ppl_nd_dangun',
#  'Q3E_do_moral',
#  'Q4E_ppl_good',
#  'Q5E_ppl_bad',
#  'Q6E_hnsty_best',
#  'Q7E_lying_bad',
#  'Q8E_ppl_lazy',
#  'Q9E_humble_hnst',
#  'Q10E_hnstly_ask',
#  'Q11E_leader_clean',
#  'Q12E_trust_trouble',
#  'Q13E_ppl_criminal',
#  'Q14E_ppl_brave',
#  'Q15E_abu_good',
#  'Q16E_ppl_good',
#  'Q17E_ppl_notbad',
#  'Q18E_komsu_better',
#  'Q19E_anrocksa_ok',
#  'Q20E_money_good']

# %%
df.loc[:, sec_col] = df.loc[:, sec_col].apply(lambda x: round(x*0.001))

# %%
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 73484              2.0  17.0           10.0                  1.0   6.0
# 73485              5.0   9.0            6.0                  5.0   4.0
# 73486              2.0  17.0            5.0                  1.0  18.0
# 73487              4.0  15.0            8.0                  3.0   9.0
# 73488              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 0                   19.0             5.0  20.0          15.0             2.0
# 1                    8.0             1.0  16.0           6.0             3.0
# 2                    3.0             1.0   2.0           7.0             1.0
# 3                   10.0             2.0   7.0          10.0             1.0
# 4                    5.0             2.0  19.0           9.0             1.0
# ...                  ...             ...   ...           ...             ...
# 73484               14.0             2.0  16.0          25.0             4.0
# 73485                4.0             1.0  15.0           7.0             1.0
# 73486                7.0             1.0   9.0           5.0             1.0
# 73487                8.0             5.0  17.0           9.0             3.0
# 73488                6.0             5.0  13.0          37.0             1.0
#
#        ...  screenh   hand               religion   orientation   race  voted  \
# 0      ...    900.0  Right      Christian(othrer)  Heterosexual  Black    Yes
# 1      ...    864.0  Right               Agnostic  Heterosexual  White     No
# 2      ...    667.0  Right                Atheist      Bisexual  Asian     No
# 3      ...    720.0  Right  Christian(Protestant)  Heterosexual  White    Yes
# 4      ...    640.0  Right    Christian(Catholic)    Homosexual  White    Yes
# ...    ...      ...    ...                    ...           ...    ...    ...
# 73484  ...   1080.0  Right                  Other  Heterosexual  Asian     No
# 73485  ...    900.0  Right                Atheist    Homosexual  White     No
# 73486  ...   1024.0  Right               Agnostic  Heterosexual  White     No
# 73487  ...    736.0  Right               Buddhist  Heterosexual  Asian    Yes
# 73488  ...    768.0  Right    Christian(Catholic)  Heterosexual  Other     No
#
#                   married  familysize  major  score
# 0       Currently married           5   True   75.0
# 1           Never married           2   True   91.0
# 2           Never married           2   True   98.0
# 3      Previously married           2   True   78.0
# 4           Never married           2   True   85.0
# ...                   ...         ...    ...    ...
# 73484   Currently married           1   True   59.0
# 73485       Never married           2   True   90.0
# 73486       Never married           3  False   69.0
# 73487       Never married           4   True   53.0
# 73488       Never married           4  False   64.0
#
# [73489 rows x 106 columns]

# %% [markdown]
# ### 이상치 확인 & 처리

# %% [markdown]
# > 0, "0", null, 이상치, 너무 다양한 데이터 외 여러 컬럼들에서 이상치 발견.
# (추후 역추적에 활용할 계획입니다. 따로 데이터프레임으로 만들어두겠습니다.)

# %% [markdown]
# #### major 컬럼 drop
# > major(전공) 컬럼 데이터는 모델링에서 제외
#  - spectrum 범주화 어려운 주관식 답변 데이터이기 때문
#  - 모델링 완료후 참여자 정보 확인용으로 활용
#  - \+ 추후 나이브베이즈로 카테고라이징 시도..?

# %%
df['major']
# Out:
# 0                     Marketing
# 1                    mathematics
# 2                      Chemistry
# 3        international relations
# 4                     Management
#                   ...
# 73484                   business
# 73485                  sociology
# 73486                        NaN
# 73487                   Business
# 73488                        NaN
# Name: major, Length: 73489, dtype: object

# %%
df.drop(columns = "major", inplace = True)

# %% [markdown]
# #### 컬럼별 '0' 데이터 확인

# %%
col_list = list(df.columns)

# %%
for sec in sec_col:        
    col_list.remove(sec)

zero_cols = []
zero_len = []


for col in col_list:  
    if 0  in df["{}".format(col)].unique():
        zero_cols.append(col)
        zero_len.append(len(df[df[col]==0]))
        
    elif "0"  in df["{}".format(col)].unique():
        zero_cols.append(col)
        zero_len.append(len(df[df[col]=="0"]))

zero_df = pd.DataFrame({"zero_len" : zero_len}, index = zero_cols)
zero_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   del sys.path[0]
#              zero_len
# introelapse         6
# TYP_out           527
# TYP_fight         601
# TYP_depnd         675
# TYP_anx           633
# TYP_try           554
# TYP_quiet         569
# TYP_warm          645
# TYP_disorg        736
# TYP_calm          552
# TYP_stable        669
# education         880
# urban             631
# gender            137
# engnat            119
# screenw           115
# screenh           115
# hand              292
# religion         1138
# orientation      1412
# race             1110
# voted             581
# married           290
# familysize       2264
# major           26338
# score               3

# %%
df[df["introelapse"]==0]
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 7305               4.0  10.0           8.53                  1.0   5.0
# 9747               5.0  15.0           9.04                  5.0  16.0
# 28198              4.0  19.0           2.57                  4.0  13.0
# 40643              5.0  10.0           0.21                  5.0  20.0
# 49531              5.0   4.0           4.30                  2.0  15.0
# 71191              5.0  15.0          13.38                  2.0   7.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 7305                5.94             1.0   1.0          7.95             5.0
# 9747               11.44             1.0   7.0          7.22             1.0
# 28198               2.53             2.0   5.0          5.05             3.0
# 40643               0.20             5.0   9.0          0.22             5.0
# 49531               4.28             3.0  14.0          4.83             2.0
# 71191               9.52             1.0  17.0          8.00             1.0
#
#        ...  screenh   hand             religion   orientation   race  voted  \
# 7305   ...    552.0  Right                Other  Heterosexual  White    Yes
# 9747   ...    125.0  Right    Christian(othrer)  Heterosexual  Black    Yes
# 28198  ...    667.0  Right             Agnostic  Heterosexual  White     No
# 40643  ...    768.0   Both               Muslim  Heterosexual  Black     No
# 49531  ...    568.0  Right    Christian(othrer)  Heterosexual  White     No
# 71191  ...    320.0  Right  Christian(Catholic)         Other  Black     No
#
#              married  familysize  major  score
# 7305   Never married           1   True   59.0
# 9747   Never married           1  False   99.0
# 28198  Never married           2  False   78.0
# 40643  Never married           9  False   60.0
# 49531  Never married           2  False   83.0
# 71191  Never married           3   True   78.0
#
# [6 rows x 106 columns]

# %% [markdown]
# **[ "0" 데이터 경향 분석 ]**
# >- 추가 설문 문항 컬럼
#     - "추가 설문"이라는 특성상 단순히 참여자가 답변하지 않고 넘어간 문항일듯... 귀찮아서였든, 척도를 판단하기 어려워서였든..
#
#
# >- 서버 자동수집 정보 컬럼
#     - 실제 intro page 머문시간이 0초인 경우인듯... 나머지 컬럼 데이터가 충실함.

# %% [markdown]
# ##### 역추적용 csv 생성

# %% [markdown]
# > 인종(race), 종교(religion) 컬럼에서 '0'데이터는 따로 데이터 프레임 만듬
# csv 파일로도 저장했습니다. __(path : MACH_data/data_in_0.csv)__

# %%
df_in_0 = df[(df['TYP_out'] == 0) | (df['TYP_fight'] == 0) | (df['TYP_depnd'] == 0) | (df['TYP_anx'] == 0) | (df['TYP_try'] == 0) |
             (df['TYP_quiet'] == 0) | (df['TYP_warm'] == 0) | (df['TYP_disorg'] == 0) | (df['TYP_calm'] == 0) | (df['TYP_stable'] == 0) |
             (df['education'] == 0) | (df['urban'] == 0) | (df['gender'] == 0) | (df['engnat'] == 0) | (df['hand'] == 0)|
             (df['orientation'] == 0)| (df['married'] == 0) | (df['race'] == 0) | (df['religion'] == 0) | (df['voted'] == 0)]
df_in_0.tail()
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 73278              5.0   6.0           6.89                  1.0  11.0
# 73320              4.0  13.0          25.69                  4.0  17.0
# 73371              5.0  10.0           5.86                  5.0  11.0
# 73405              5.0  11.0          27.55                  4.0   5.0
# 73410              1.0  20.0           0.35                  4.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 73278               4.66             3.0   9.0         17.52             1.0
# 73320              25.16             2.0  10.0         38.45             3.0
# 73371               2.63             1.0   4.0          5.44             1.0
# 73405              42.47             3.0  15.0         44.50             3.0
# 73410               0.36             3.0  12.0          0.25             3.0
#
#        ...  screenh   hand             religion   orientation   race  voted  \
# 73278  ...    640.0  Right               Muslim  Heterosexual  Other     No
# 73320  ...   1080.0  Right                    0             0  Asian     No
# 73371  ...    848.0  Right                Other  Heterosexual  Other     No
# 73405  ...    667.0  Right             Agnostic  Heterosexual  Asian    Yes
# 73410  ...    667.0  Right  Christian(Catholic)    Homosexual  Black    Yes
#
#                   married  familysize  major  score
# 73278   Currently married           4   True   62.0
# 73320       Never married           0   True   73.0
# 73371  Previously married           2  False   90.0
# 73405       Never married           2   True   71.0
# 73410       Never married           1   True   60.0
#
# [5 rows x 106 columns]

# %%
df_in_0.index
# Out:
# Int64Index([   14,    27,    75,   244,   251,   289,   296,   383,   396,
#               407,
#             ...
#             73107, 73130, 73193, 73220, 73233, 73278, 73320, 73371, 73405,
#             73410],
#            dtype='int64', length=1585)

# %%
df_in_0.to_csv('./MACH_data/data_in_0.csv')

# %% [markdown]
# > 인종(race), 종교(religion) 컬럼에서 '0'데이터를 제외한
# 데이터 프레임, csv파일로 저장했습니다.

# %%
df.drop(df_in_0.index, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.tail()
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 71899              2.0  17.0           9.93                  1.0   6.0
# 71900              5.0   9.0           5.82                  5.0   4.0
# 71901              2.0  17.0           5.35                  1.0  18.0
# 71902              4.0  15.0           7.97                  3.0   9.0
# 71903              3.0  12.0           7.57                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 71899              14.22             2.0  16.0         25.50             4.0
# 71900               4.37             1.0  15.0          7.25             1.0
# 71901               6.85             1.0   9.0          4.92             1.0
# 71902               7.90             5.0  17.0          8.65             3.0
# 71903               5.77             5.0  13.0         37.10             1.0
#
#        ...  screenh   hand             religion   orientation   race  voted  \
# 71899  ...   1080.0  Right                Other  Heterosexual  Asian     No
# 71900  ...    900.0  Right              Atheist    Homosexual  White     No
# 71901  ...   1024.0  Right             Agnostic  Heterosexual  White     No
# 71902  ...    736.0  Right             Buddhist  Heterosexual  Asian    Yes
# 71903  ...    768.0  Right  Christian(Catholic)  Heterosexual  Other     No
#
#                  married  familysize  major  score
# 71899  Currently married           1   True   59.0
# 71900      Never married           2   True   90.0
# 71901      Never married           3  False   69.0
# 71902      Never married           4   True   53.0
# 71903      Never married           4  False   64.0
#
# [5 rows x 106 columns]

# %% [markdown]
# #### age 컬럼 이상치 -> `미완성`

# %%
## 전세계 인간 평균 수명 기준 이상되는 data를 drop하는 거 어떨까?
 - 
 -

# %%
df['age'].plot(kind='box')

# %%
df_age = pd.DataFrame(df['age'].value_counts())
df_age
# Out:
#          age
# 18      4389
# 17      3767
# 20      3542
# 21      3423
# 19      3364
# ...      ...
# 476        1
# 662        1
# 87         1
# 999999     1
# 410        1
#
# [98 rows x 1 columns]

# %%
df_age[df_age.values < 5]
# Out:
#          age
# 84         4
# 88         4
# 99         3
# 81         3
# 100        2
# 83         2
# 85         2
# 92         2
# 91         2
# 90         2
# 1989       1
# 321        1
# 310        1
# 1984       1
# 280        1
# 9000       1
# 1996       1
# 500        1
# 1997       1
# 110        1
# 999        1
# 9000009    1
# 338        1
# 225        1
# 476        1
# 662        1
# 87         1
# 999999     1
# 410        1

# %%
df_age[df_age.index > 100]
# Out:
#          age
# 1989       1
# 321        1
# 310        1
# 1984       1
# 280        1
# 9000       1
# 1996       1
# 500        1
# 1997       1
# 110        1
# 999        1
# 9000009    1
# 338        1
# 225        1
# 476        1
# 662        1
# 999999     1
# 410        1

# %% [markdown]
# #### familysize (가족단위) 컬럼 -> `미완성`

# %%
## 본 데이터의 top3 국가의 가족단위 통계자료 확인 후 이상치 처리 기준 수립

# %%
df['familysize'].plot(kind='box')

# %%
df['familysize'].value_counts()
# Out:
# 2             28507
# 3             17326
# 1             10874
# 4              7431
# 5              2953
# 0              2195
# 6              1256
# 7               593
# 8               336
# 9               180
# 10               87
# 11               57
# 12               41
# 14               16
# 13               14
# 15                9
# 17                3
# 44                3
# 20                3
# 21                3
# 16                2
# 96                1
# 2147483647        1
# 999               1
# 100               1
# 67                1
# 34                1
# 2137              1
# 30                1
# 24                1
# 900000            1
# 23                1
# 22                1
# 18                1
# 236               1
# 48                1
# Name: familysize, dtype: int64

# %% [markdown]
# #### 컬럼별 null 데이터 확인 후 drop

# %%
df.isnull().sum().plot(kind='bar', figsize=(16, 6))

# %%
## Q~ 마키아벨리즘 테스트 문항 결측치 => score 컬럼 생성시 확인한 정보 기반 drop

# %%
df[df["score"]==0.0].index
# Out:
# Int64Index([25749, 30431, 32711], dtype='int64')

# %%
## Q~ 제외 나머지 결측치 drop

# %%
idx_d = [25749, 30431, 32711]
cols = ['country', 'introelapse', 'testelapse', 'screenh', 'screenw']
for x in cols:
    for i in df[df[x].isnull()].index:
        idx_d.append(i)

# %%
df.drop(idx_d, inplace=True)

# %%
df.isnull().sum().plot(kind='bar', figsize=(16, 6))

# %% [markdown]
# ### EDA용 csv 생성

# %%
df.to_csv('./MACH_data/data_for_eda.csv', index=False)

# %% [markdown]
# ## sweetviz 리포트 생성

# %%
import sweetviz as sv

# %%
df_eda = pd.read_csv('./MACH_data/data_for_eda.csv')
df_eda.head()
# Out:
#    Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0              3.0   6.0          21.02                  3.0   7.0
# 1              5.0  17.0           3.82                  5.0   9.0
# 2              5.0  16.0           4.19                  5.0  12.0
# 3              2.0  12.0           9.37                  4.0   1.0
# 4              5.0  13.0           9.46                  5.0   7.0
#
#    Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  ...  \
# 0              18.60             5.0  20.0         14.96             2.0  ...
# 1               7.85             1.0  16.0          5.90             3.0  ...
# 2               2.90             1.0   2.0          7.16             1.0  ...
# 3              10.17             2.0   7.0         10.12             1.0  ...
# 4               5.28             2.0  19.0          8.87             1.0  ...
#
#    screenh   hand               religion   orientation   race  voted  \
# 0    900.0  Right      Christian(othrer)  Heterosexual  Black    Yes
# 1    864.0  Right               Agnostic  Heterosexual  White     No
# 2    667.0  Right                Atheist      Bisexual  Asian     No
# 3    720.0  Right  Christian(Protestant)  Heterosexual  White    Yes
# 4    640.0  Right    Christian(Catholic)    Homosexual  White    Yes
#
#               married  familysize  major  score
# 0   Currently married           5   True   75.0
# 1       Never married           2   True   91.0
# 2       Never married           2   True   98.0
# 3  Previously married           2   True   78.0
# 4       Never married           2   True   85.0
#
# [5 rows x 106 columns]

# %%
data_rep = sv.analyze(df_eda)
# Out:
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=107.0), HTML(value='')), layout=Layout(di…
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=106.0), HTML(value='')), layout=Layout(di…
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=1.0), HTML(value='')), layout=Layout(disp…

# %%
data_rep.show_html('sweetviz_test.html')
# Out:
# Report sweetviz_test.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### 리포트 확인 후 컬럼 재확인 -> ```확인!!!```

# %% [markdown]
# > 1. Q_ 컬럼들에서 A는 주로 어떤질문에 어떤 답변이 많았는지 체크
# 2. age의 이상치 발견 `100세 이상 데이터 어떻게??`
# 3. race, religion의 '0' `어떻게 처리할까요??`
# 4. TYP 컬럼들에서 주로 무슨 답변을 했을지 체크
# 5. VCL 컬럼도 "신뢰성" 점수 만들어서 컬럼 하나짜리 생성 ㄱ..?
# 6. QE 답변 시간 데이터 소숫점 2자리까지 하니까 spectrum 너무 다양.. 소숫점 1자리까지 반올림 ㄱ..?

# %%
df_eda['age'].plot(kind='box')

# %%
df_eda['age'].value_counts()
# Out:
# 18        4389
# 17        3766
# 20        3542
# 21        3422
# 19        3363
#           ...
# 476          1
# 662          1
# 87           1
# 999999       1
# 410          1
# Name: age, Length: 98, dtype: int64

# %%
age_value = pd.DataFrame(df_eda['age'].value_counts())
age_value
# Out:
#          age
# 18      4389
# 17      3766
# 20      3542
# 21      3422
# 19      3363
# ...      ...
# 476        1
# 662        1
# 87         1
# 999999     1
# 410        1
#
# [98 rows x 1 columns]

# %%
age_value[age_value.values < 5]
# Out:
#          age
# 84         4
# 88         4
# 99         3
# 81         3
# 100        2
# 83         2
# 85         2
# 92         2
# 91         2
# 90         2
# 1989       1
# 321        1
# 310        1
# 1984       1
# 280        1
# 9000       1
# 1996       1
# 500        1
# 1997       1
# 110        1
# 999        1
# 9000009    1
# 338        1
# 225        1
# 476        1
# 662        1
# 87         1
# 999999     1
# 410        1

# %%
age_value[age_value.index >= 100]
# Out:
#          age
# 100        2
# 1989       1
# 321        1
# 310        1
# 1984       1
# 280        1
# 9000       1
# 1996       1
# 500        1
# 1997       1
# 110        1
# 999        1
# 9000009    1
# 338        1
# 225        1
# 476        1
# 662        1
# 999999     1
# 410        1

# %% [markdown]
# ### compare_intra 사용

# %% [markdown]
# > voted에서 0데이터 발견... __`임시로 no로 체크`__

# %%
df_eda['voted'].value_counts()
# Out:
# No     39662
# Yes    31681
# 0        543
# Name: voted, dtype: int64

# %%
df_eda['voted'] = df_eda['voted'].str.replace('0', "No")

# %%
df_eda['voted'].value_counts()
# Out:
# No     40205
# Yes    31681
# Name: voted, dtype: int64

# %%
cates.keys()
# Out:
# dict_keys(['education', 'urban', 'gender', 'engnat', 'hand', 'religion', 'orientation', 'race', 'voted', 'married'])

# %%
feature_config = sv.FeatureConfig(force_cat=['education', 'urban', 'gender', 'engnat', 'hand', 'religion', 'orientation', 'race', 'voted', 'married'])

# %%
comint_rep = sv.compare_intra(df_eda, df_eda['voted'] == "Yes", ["Yes", "No"])
# Out:
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=107.0), HTML(value='')), layout=Layout(di…
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=106.0), HTML(value='')), layout=Layout(di…
# HBox(children=(FloatProgress(value=0.0, layout=Layout(flex='2'), max=1.0), HTML(value='')), layout=Layout(disp…

# %%
comint_rep.show_html('sweetviz_compare_voted.html')
# Out:
# Report sweetviz_compare_voted.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
