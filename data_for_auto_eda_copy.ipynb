# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#sweetviz용-데이터-전처리" data-toc-modified-id="sweetviz용-데이터-전처리-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>sweetviz용 데이터 전처리</a></span><ul class="toc-item"><li><span><a href="#전체-데이터-불러오기" data-toc-modified-id="전체-데이터-불러오기-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>전체 데이터 불러오기</a></span></li><li><span><a href="#컬럼명-수정" data-toc-modified-id="컬럼명-수정-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>컬럼명 수정</a></span></li><li><span><a href="#컬럼-추가" data-toc-modified-id="컬럼-추가-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>컬럼 추가</a></span><ul class="toc-item"><li><span><a href="#score-컬럼" data-toc-modified-id="score-컬럼-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>score 컬럼</a></span></li><li><span><a href="#V,-T,-M-컬럼" data-toc-modified-id="V,-T,-M-컬럼-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>V, T, M 컬럼</a></span></li></ul></li><li><span><a href="#데이터-변환" data-toc-modified-id="데이터-변환-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>데이터 변환</a></span><ul class="toc-item"><li><span><a href="#숫자형-데이터-=>-텍스트-데이터" data-toc-modified-id="숫자형-데이터-=>-텍스트-데이터-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>숫자형 데이터 =&gt; 텍스트 데이터</a></span></li><li><span><a href="#시간-데이터-단위변환" data-toc-modified-id="시간-데이터-단위변환-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>시간 데이터 단위변환</a></span></li></ul></li><li><span><a href="#이상치-확인-&amp;-처리" data-toc-modified-id="이상치-확인-&amp;-처리-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>이상치 확인 &amp; 처리</a></span><ul class="toc-item"><li><span><a href="#major-컬럼-drop" data-toc-modified-id="major-컬럼-drop-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>major 컬럼 drop</a></span></li><li><span><a href="#컬럼별-null-데이터-확인-후-drop" data-toc-modified-id="컬럼별-null-데이터-확인-후-drop-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>컬럼별 null 데이터 확인 후 drop</a></span></li><li><span><a href="#컬럼별-'0'-데이터-확인" data-toc-modified-id="컬럼별-'0'-데이터-확인-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>컬럼별 '0' 데이터 확인</a></span><ul class="toc-item"><li><span><a href="#역추적용-csv-생성" data-toc-modified-id="역추적용-csv-생성-1.5.3.1"><span class="toc-item-num">1.5.3.1&nbsp;&nbsp;</span>역추적용 csv 생성</a></span></li></ul></li><li><span><a href="#age-(나이)-컬럼-이상치-처리" data-toc-modified-id="age-(나이)-컬럼-이상치-처리-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>age (나이) 컬럼 이상치 처리</a></span><ul class="toc-item"><li><span><a href="#기네스-최대수명-기준-이상치-제거" data-toc-modified-id="기네스-최대수명-기준-이상치-제거-1.5.4.1"><span class="toc-item-num">1.5.4.1&nbsp;&nbsp;</span>기네스 최대수명 기준 이상치 제거</a></span></li><li><span><a href="#미국인--평균수명-기준" data-toc-modified-id="미국인--평균수명-기준-1.5.4.2"><span class="toc-item-num">1.5.4.2&nbsp;&nbsp;</span>미국인  평균수명 기준</a></span></li></ul></li><li><span><a href="#familysize-(가족단위)-컬럼-이상치-처리" data-toc-modified-id="familysize-(가족단위)-컬럼-이상치-처리-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>familysize (가족단위) 컬럼 이상치 처리</a></span><ul class="toc-item"><li><span><a href="#기네스-최대-가족구성원-수-기준" data-toc-modified-id="기네스-최대-가족구성원-수-기준-1.5.5.1"><span class="toc-item-num">1.5.5.1&nbsp;&nbsp;</span>기네스 최대 가족구성원 수 기준</a></span></li><li><span><a href="#미국인-평균-가족-구성원-수-기준" data-toc-modified-id="미국인-평균-가족-구성원-수-기준-1.5.5.2"><span class="toc-item-num">1.5.5.2&nbsp;&nbsp;</span>미국인 평균 가족 구성원 수 기준</a></span></li></ul></li></ul></li><li><span><a href="#EDA용-csv-생성" data-toc-modified-id="EDA용-csv-생성-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>EDA용 csv 생성</a></span></li></ul></li><li><span><a href="#sweetviz-리포트-생성" data-toc-modified-id="sweetviz-리포트-생성-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>sweetviz 리포트 생성</a></span><ul class="toc-item"><li><span><a href="#리포트-확인-후-컬럼-재확인-->-확인!!!" data-toc-modified-id="리포트-확인-후-컬럼-재확인-->-확인!!!-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>리포트 확인 후 컬럼 재확인 -&gt; <code>확인!!!</code></a></span></li><li><span><a href="#compare_intra-사용" data-toc-modified-id="compare_intra-사용-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>compare_intra 사용</a></span></li></ul></li><li><span><a href="#모델" data-toc-modified-id="모델-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>모델</a></span><ul class="toc-item"><li><span><a href="#auto-ml" data-toc-modified-id="auto-ml-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>auto ml</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## sweetviz용 데이터 전처리

# %% [markdown]
# ### 전체 데이터 불러오기

# %%
df = pd.read_csv('./MACH_data/data.csv', delimiter='\t')
df
# Out:
#        Q1A   Q1I      Q1E  Q2A   Q2I      Q2E  Q3A   Q3I      Q3E  Q4A  ...  \
# 0      3.0   6.0  21017.0  3.0   7.0  18600.0  5.0  20.0  14957.0  2.0  ...
# 1      5.0  17.0   3818.0  5.0   9.0   7850.0  1.0  16.0   5902.0  3.0  ...
# 2      5.0  16.0   4186.0  5.0  12.0   2900.0  1.0   2.0   7160.0  1.0  ...
# 3      2.0  12.0   9373.0  4.0   1.0  10171.0  2.0   7.0  10117.0  1.0  ...
# 4      5.0  13.0   9465.0  5.0   7.0   5284.0  2.0  19.0   8872.0  1.0  ...
# ...    ...   ...      ...  ...   ...      ...  ...   ...      ...  ...  ...
# 73484  2.0  17.0   9925.0  1.0   6.0  14218.0  2.0  16.0  25499.0  4.0  ...
# 73485  5.0   9.0   5816.0  5.0   4.0   4368.0  1.0  15.0   7246.0  1.0  ...
# 73486  2.0  17.0   5353.0  1.0  18.0   6846.0  1.0   9.0   4920.0  1.0  ...
# 73487  4.0  15.0   7974.0  3.0   9.0   7901.0  5.0  17.0   8647.0  3.0  ...
# 73488  3.0  12.0   7567.0  1.0  10.0   5766.0  5.0  13.0  37103.0  1.0  ...
#
# ...

# %% [markdown]
# ### 컬럼명 수정

# %% [markdown]
# > 컬럼명에 컬럼 정보 추가하여 수정
# > - 직관적 EDA 수행 목적

# %%
df.rename(columns = {"Q1A" : "Q1_TP_notell_2u", "Q2A" : "Q2_TP_ppl_nd_dangun", "Q3A" : "Q3_TN_do_moral", "Q4A" : "Q4_VN_ppl_good", "Q5A" : "Q5_VP_ppl_bad", "Q6A" : "Q6_TN_hnsty_best", "Q7A" : "Q7_TN_lying_bad", "Q8A" : "Q8_VP_ppl_lazy", "Q9A" : "Q9_MN_humble_hnst", "Q10A" : "Q10_TN_hnstly_ask", "Q11A" : "Q11_VN_leader_clean", "Q12A" : "Q12_TP_trust_trouble", "Q13A" : "Q13_VP_ppl_criminal", "Q14A" : "Q14_VN_ppl_brave", "Q15A" : "Q15_TP_abu_good", "Q16A" : "Q16_TN_ppl_good", "Q17A" : "Q17_VN_ppl_notbad", "Q18A" : "Q18_VP_komsu_better", "Q19A" : "Q19_MP_anrocksa_ok", "Q20A" : "Q20_VP_money_good",
                     "Q1E" : "Q1E_notell_2u", "Q2E" : "Q2E_ppl_nd_dangun", "Q3E" : "Q3E_do_moral", "Q4E" : "Q4E_ppl_good", "Q5E" : "Q5E_ppl_bad", "Q6E" : "Q6E_hnsty_best", "Q7E" : "Q7E_lying_bad", "Q8E" : "Q8E_ppl_lazy", "Q9E" : "Q9E_humble_hnst", "Q10E" : "Q10E_hnstly_ask", "Q11E" : "Q11E_leader_clean", "Q12E" : "Q12E_trust_trouble", "Q13E" : "Q13E_ppl_criminal", "Q14E" : "Q14E_ppl_brave", "Q15E" : "Q15E_abu_good", "Q16E" : "Q16E_ppl_good", "Q17E" : "Q17E_ppl_notbad", "Q18E" : "Q18E_komsu_better", "Q19E" : "Q19E_anrocksa_ok", "Q20E" : "Q20E_money_good",
                     "TIPI1":"TYP_out", "TIPI2":"TYP_fight", "TIPI3":"TYP_depnd", "TIPI4":"TYP_anx", "TIPI5":"TYP_try", "TIPI6":"TYP_quiet", "TIPI7":"TYP_warm", "TIPI8":"TYP_disorg", "TIPI9":"TYP_calm", "TIPI10":"TYP_stable",
                     "VCL6" : "VCL6_F", "VCL9" : "VCL9_F", "VCL12" : "VCL12_F"
                    }, inplace=True)

# %%
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0        21017.0                  3.0   7.0
# 1                  5.0  17.0         3818.0                  5.0   9.0
# 2                  5.0  16.0         4186.0                  5.0  12.0
# 3                  2.0  12.0         9373.0                  4.0   1.0
# 4                  5.0  13.0         9465.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 73484              2.0  17.0         9925.0                  1.0   6.0
# 73485              5.0   9.0         5816.0                  5.0   4.0
# 73486              2.0  17.0         5353.0                  1.0  18.0
# 73487              4.0  15.0         7974.0                  3.0   9.0
# 73488              3.0  12.0         7567.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %% [markdown]
# ### 컬럼 추가

# %%
col_list = list(df.columns)

# %% [markdown]
# #### score 컬럼

# %% [markdown]
# > 테스트 참여자의 마키아벨리즘에 대한 수용 수준 점수화
# - 점수화 소스 데이터
#     - 마키아벨리즘 test 답변 점수
#     - 1점(Disagree) ~ 5점(Agree)
# >
# >
# - 점수화 공식
#     - ```수용적 경향 질문지 답변 점수의 합```  +  ```불수용적 경향 질문지 답변 점수의 역변환 값 (6-점수) ```

# %%
pos_col = []
neg_col = []

for col in col_list:
    if "P" in col and "Y" not in col:
        pos_col.append(col)
    if "N" in col:
        neg_col.append(col)
        
print(pos_col, '\n', '\n', neg_col)
# Out:
# ['Q1_TP_notell_2u', 'Q2_TP_ppl_nd_dangun', 'Q5_VP_ppl_bad', 'Q8_VP_ppl_lazy', 'Q12_TP_trust_trouble', 'Q13_VP_ppl_criminal', 'Q15_TP_abu_good', 'Q18_VP_komsu_better', 'Q19_MP_anrocksa_ok', 'Q20_VP_money_good']
#
#  ['Q3_TN_do_moral', 'Q4_VN_ppl_good', 'Q6_TN_hnsty_best', 'Q7_TN_lying_bad', 'Q9_MN_humble_hnst', 'Q10_TN_hnstly_ask', 'Q11_VN_leader_clean', 'Q14_VN_ppl_brave', 'Q16_TN_ppl_good', 'Q17_VN_ppl_notbad']

# %%
df["score"] = df[pos_col].sum(axis=1) + df[neg_col].apply(lambda x: 6 -x).sum(axis=1)
df["score"]
# Out:
# 0        75.0
# 1        91.0
# 2        98.0
# 3        78.0
# 4        85.0
#          ...
# 73484    59.0
# 73485    90.0
# 73486    69.0
# 73487    53.0
# 73488    64.0
# Name: score, Length: 73489, dtype: float64

# %%
df["score"].describe()
# Out:
# count    73489.000000
# mean        67.681531
# std         15.783480
# min          0.000000
# 25%         56.000000
# 50%         68.000000
# 75%         80.000000
# max        100.000000
# Name: score, dtype: float64

# %%
## 결측치 포착..
df[df["score"]==0.0]
# Out:
#        Q1_TP_notell_2u  Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun  Q2I  \
# 26286              NaN  NaN            NaN                  NaN  NaN
# 31072              NaN  NaN            NaN                  NaN  NaN
# 33399              NaN  NaN            NaN                  NaN  NaN
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral  Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 26286                NaN             NaN  NaN           NaN             NaN
# 31072                NaN             NaN  NaN           NaN             NaN
# 33399                NaN             NaN  NaN           NaN             NaN
#
#        ...  screenh  hand  religion  orientation  race  voted  married  \
# 26286  ...    640.0     1         2            1    20      2        1
# 31072  ...    900.0     1         6            1    30      1        2
# 33399  ...    768.0     1         4            1    60      2        2
#
#        familysize                   major  score
# ...

# %% [markdown]
# #### V, T, M 컬럼

# %%
a = 6 - df.loc[:,neg_col]
b = df.loc[:,pos_col]
c = pd.concat([a,b], axis=1)
d=list(c.columns)
d
# Out:
# ['Q3_TN_do_moral',
#  'Q4_VN_ppl_good',
#  'Q6_TN_hnsty_best',
#  'Q7_TN_lying_bad',
#  'Q9_MN_humble_hnst',
#  'Q10_TN_hnstly_ask',
#  'Q11_VN_leader_clean',
#  'Q14_VN_ppl_brave',
#  'Q16_TN_ppl_good',
#  'Q17_VN_ppl_notbad',
#  'Q1_TP_notell_2u',
#  'Q2_TP_ppl_nd_dangun',
#  'Q5_VP_ppl_bad',
#  'Q8_VP_ppl_lazy',
#  'Q12_TP_trust_trouble',
#  'Q13_VP_ppl_criminal',
#  'Q15_TP_abu_good',
#  'Q18_VP_komsu_better',
#  'Q19_MP_anrocksa_ok',
#  'Q20_VP_money_good']

# %%
v_score = []
t_score = []
m_score = []

for col in d:
    if "T" in col:
        t_score.append(col)
    if "M" in col:
        m_score.append(col)
    if "V" in col:
        v_score.append(col)
        
print(t_score, '\n', m_score, '\n', v_score)
# Out:
# ['Q3_TN_do_moral', 'Q6_TN_hnsty_best', 'Q7_TN_lying_bad', 'Q10_TN_hnstly_ask', 'Q16_TN_ppl_good', 'Q1_TP_notell_2u', 'Q2_TP_ppl_nd_dangun', 'Q12_TP_trust_trouble', 'Q15_TP_abu_good']
#  ['Q9_MN_humble_hnst', 'Q19_MP_anrocksa_ok']
#  ['Q4_VN_ppl_good', 'Q11_VN_leader_clean', 'Q14_VN_ppl_brave', 'Q17_VN_ppl_notbad', 'Q5_VP_ppl_bad', 'Q8_VP_ppl_lazy', 'Q13_VP_ppl_criminal', 'Q18_VP_komsu_better', 'Q20_VP_money_good']

# %%
df["v_score"] = c[v_score].sum(axis=1)

# %%
df["t_score"] = c[t_score].sum(axis=1)

# %%
df["m_score"] = c[m_score].sum(axis=1)

# %%
df["score"]
# Out:
# 0        75.0
# 1        91.0
# 2        98.0
# 3        78.0
# 4        85.0
#          ...
# 73484    59.0
# 73485    90.0
# 73486    69.0
# 73487    53.0
# 73488    64.0
# Name: score, Length: 73489, dtype: float64

# %%
df[["v_score", "t_score", "m_score"]].sum(axis=1)
# Out:
# 0        75.0
# 1        91.0
# 2        98.0
# 3        78.0
# 4        85.0
#          ...
# 73484    59.0
# 73485    90.0
# 73486    69.0
# 73487    53.0
# 73488    64.0
# Length: 73489, dtype: float64

# %%
df.head()
# Out:
#    Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0              3.0   6.0        21017.0                  3.0   7.0
# 1              5.0  17.0         3818.0                  5.0   9.0
# 2              5.0  16.0         4186.0                  5.0  12.0
# 3              2.0  12.0         9373.0                  4.0   1.0
# 4              5.0  13.0         9465.0                  5.0   7.0
#
#    Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  ...  \
# 0            18600.0             5.0  20.0       14957.0             2.0  ...
# 1             7850.0             1.0  16.0        5902.0             3.0  ...
# 2             2900.0             1.0   2.0        7160.0             1.0  ...
# 3            10171.0             2.0   7.0       10117.0             1.0  ...
# 4             5284.0             2.0  19.0        8872.0             1.0  ...
#
#    orientation  race  voted  married  familysize                    major  \
# ...

# %% [markdown]
# ### 데이터 변환

# %%
vcl_col = []
sec_col = []

for col in col_list:
    if "VCL" in col:
        vcl_col.append(col)
    if "E" in col:
        sec_col.append(col)
print(vcl_col, '\n', '\n', sec_col)
# Out:
# ['VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6_F', 'VCL7', 'VCL8', 'VCL9_F', 'VCL10', 'VCL11', 'VCL12_F', 'VCL13', 'VCL14', 'VCL15', 'VCL16']
#
#  ['Q1E_notell_2u', 'Q2E_ppl_nd_dangun', 'Q3E_do_moral', 'Q4E_ppl_good', 'Q5E_ppl_bad', 'Q6E_hnsty_best', 'Q7E_lying_bad', 'Q8E_ppl_lazy', 'Q9E_humble_hnst', 'Q10E_hnstly_ask', 'Q11E_leader_clean', 'Q12E_trust_trouble', 'Q13E_ppl_criminal', 'Q14E_ppl_brave', 'Q15E_abu_good', 'Q16E_ppl_good', 'Q17E_ppl_notbad', 'Q18E_komsu_better', 'Q19E_anrocksa_ok', 'Q20E_money_good']

# %% [markdown]
# #### 숫자형 데이터 => 텍스트 데이터

# %% [markdown]
# > 숫자로 라벨링된 범주형 데이터를 텍스트 데이터로 변경
# > - 직관적 EDA 수행 목적

# %%
df[vcl_col] = df[vcl_col].applymap(lambda x: str(x).replace("1", "know") if x==1 else str(x).replace("0", "n_know"))

# %%
df[vcl_col].head()
# Out:
#    VCL1    VCL2    VCL3  VCL4  VCL5  VCL6_F    VCL7    VCL8  VCL9_F VCL10  \
# 0  know    know  n_know  know  know  n_know  n_know    know  n_know  know
# 1  know    know    know  know  know  n_know  n_know    know  n_know  know
# 2  know    know    know  know  know    know  n_know    know    know  know
# 3  know    know    know  know  know  n_know  n_know    know  n_know  know
# 4  know  n_know  n_know  know  know  n_know  n_know  n_know  n_know  know
#
#     VCL11 VCL12_F   VCL13   VCL14 VCL15 VCL16
# 0    know    know    know    know  know  know
# 1  n_know  n_know    know    know  know  know
# 2    know    know    know    know  know  know
# 3  n_know    know  n_know    know  know  know
# 4  n_know  n_know  n_know  n_know  know  know

# %%
def tran_cate(df, cate, x, y):
    df[cate] = df[cate].astype('str').replace(x, y)
    return df[cate]

# %%
cates = {
    'education' : ['Less than high school','High school','University degree','Graduate degree'],
    'urban' : ['Rural','Suburban','Urban'],
    'gender' : ['Male','Female','Other'],
    'engnat' : ['Yes','No'],
    'hand' : ['Right','Left','Both'],
    'religion' : ['Agnostic','Atheist','Buddhist','Christian(Catholic)','Christian(Mormon)','Christian(Protestant)','Christian(othrer)','Hindu','Jewish','Muslim','Sikh','Other'],
    'orientation' : ['Heterosexual','Bisexual','Homosexual','Asexual','Other'],
    'race' : ['Asian','Arab','Black','Indigenous Australian','Native American','White','Other'],
    'voted' : ['Yes','No'],
    'married' : ['Never married','Currently married','Previously married'],
}

# %%
for x in list(cates.keys()):
    for idx, y in enumerate(cates[x]):
        if x == 'race':
            tran_cate(df, x, "{}".format((idx+1)*10) ,y)
        else:    
            tran_cate(df, x, "{}".format(idx+1) ,y)

# %%
df.head()
# Out:
#    Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0              3.0   6.0        21017.0                  3.0   7.0
# 1              5.0  17.0         3818.0                  5.0   9.0
# 2              5.0  16.0         4186.0                  5.0  12.0
# 3              2.0  12.0         9373.0                  4.0   1.0
# 4              5.0  13.0         9465.0                  5.0   7.0
#
#    Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  ...  \
# 0            18600.0             5.0  20.0       14957.0             2.0  ...
# 1             7850.0             1.0  16.0        5902.0             3.0  ...
# 2             2900.0             1.0   2.0        7160.0             1.0  ...
# 3            10171.0             2.0   7.0       10117.0             1.0  ...
# 4             5284.0             2.0  19.0        8872.0             1.0  ...
#
#     orientation   race  voted             married  familysize  \
# ...

# %% [markdown]
# #### 시간 데이터 단위변환

# %% [markdown]
# > 답변 시간 데이터를 밀리초 => 초단위로 환산

# %%
sec_col = []

for col in col_list:
    if "E" in col:
        sec_col.append(col)
sec_col
# Out:
# ['Q1E_notell_2u',
#  'Q2E_ppl_nd_dangun',
#  'Q3E_do_moral',
#  'Q4E_ppl_good',
#  'Q5E_ppl_bad',
#  'Q6E_hnsty_best',
#  'Q7E_lying_bad',
#  'Q8E_ppl_lazy',
#  'Q9E_humble_hnst',
#  'Q10E_hnstly_ask',
#  'Q11E_leader_clean',
#  'Q12E_trust_trouble',
#  'Q13E_ppl_criminal',
#  'Q14E_ppl_brave',
#  'Q15E_abu_good',
#  'Q16E_ppl_good',
#  'Q17E_ppl_notbad',
#  'Q18E_komsu_better',
#  'Q19E_anrocksa_ok',
#  'Q20E_money_good']

# %%
df[sec_col] = df[sec_col].apply(lambda x: round(x*0.001))

# %%
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 73484              2.0  17.0           10.0                  1.0   6.0
# 73485              5.0   9.0            6.0                  5.0   4.0
# 73486              2.0  17.0            5.0                  1.0  18.0
# 73487              4.0  15.0            8.0                  3.0   9.0
# 73488              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %% [markdown]
# ### 이상치 확인 & 처리

# %% [markdown]
# > 0, "0", null, 이상치, spectrum이 넓은 범주형 데이터 등 각 컬럼 내 이상치 처리
# - 이상치에 따라 추후 역추적에 활용할 계획입니다. 따로 데이터프레임으로 만들어두겠습니다.)

# %% [markdown]
# #### major 컬럼 drop
# > major(전공) 컬럼 데이터는 모델링에서 제외
#  - spectrum 범주화 어려운 주관식 답변 데이터이기 때문
#  - 모델링 완료후 참여자 정보 확인용으로 활용
#  - \+ 추후 나이브베이즈로 카테고라이징 시도..?

# %%
df['major']
# Out:
# 0                     Marketing
# 1                    mathematics
# 2                      Chemistry
# 3        international relations
# 4                     Management
#                   ...
# 73484                   business
# 73485                  sociology
# 73486                        NaN
# 73487                   Business
# 73488                        NaN
# Name: major, Length: 73489, dtype: object

# %%
df.drop(columns = "major", inplace = True)

# %% [markdown]
# #### 컬럼별 null 데이터 확인 후 drop

# %%
df.isnull().sum().plot(kind='bar', figsize=(16, 6))

# %%
## Q~ 마키아벨리즘 테스트 문항 결측치 => score 컬럼 생성시 확인한 정보 기반 drop

# %%
df[df["score"]==0.0].index
# Out:
# Int64Index([26286, 31072, 33399], dtype='int64')

# %%
## Q~ 제외 나머지 결측치 drop

# %%
idx_d = [25749, 30431, 32711]
cols = ['country', 'introelapse', 'testelapse', 'screenh', 'screenw']
for x in cols:
    for i in df[df[x].isnull()].index:
        idx_d.append(i)

# %%
df.drop(idx_d, inplace=True)

# %%
df.isnull().sum().plot(kind='bar', figsize=(16, 6))

# %% [markdown]
# #### 컬럼별 '0' 데이터 확인

# %%
col_list = list(df.columns)

# %%
for sec in sec_col:        
    col_list.remove(sec)

zero_cols = []
zero_len = []


for col in col_list:  
    if 0  in df["{}".format(col)].unique():
        zero_cols.append(col)
        zero_len.append(len(df[df[col]==0]))
        
    elif "0"  in df["{}".format(col)].unique():
        zero_cols.append(col)
        zero_len.append(len(df[df[col]=="0"]))

zero_df = pd.DataFrame({"zero_len" : zero_len}, index = zero_cols)
zero_df
# Out:
# C:\Users\82106\Anaconda3\envs\fc14th\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   del sys.path[0]
# C:\Users\82106\Anaconda3\envs\fc14th\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   del sys.path[0]
# C:\Users\82106\Anaconda3\envs\fc14th\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   del sys.path[0]
# C:\Users\82106\Anaconda3\envs\fc14th\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   del sys.path[0]
#              zero_len
# introelapse         6
# TYP_out           527
# ...

# %%
df[df["introelapse"]==0]
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 7305               4.0  10.0            9.0                  1.0   5.0
# 9747               5.0  15.0            9.0                  5.0  16.0
# 28198              4.0  19.0            3.0                  4.0  13.0
# 40643              5.0  10.0            0.0                  5.0  20.0
# 49531              5.0   4.0            4.0                  2.0  15.0
# 71191              5.0  15.0           13.0                  2.0   7.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 7305                 6.0             1.0   1.0           8.0             5.0
# 9747                11.0             1.0   7.0           7.0             1.0
# 28198                3.0             2.0   5.0           5.0             3.0
# 40643                0.0             5.0   9.0           0.0             5.0
# 49531                4.0             3.0  14.0           5.0             2.0
# ...

# %% [markdown]
# **[ "0" 데이터 경향 분석 ]**
# >- 추가 설문 문항 컬럼
#     - "추가 설문"이라는 특성상 단순히 참여자가 답변하지 않고 넘어간 문항일듯... 귀찮아서였든, 척도를 판단하기 어려워서였든..
#
#
# >- 서버 자동수집 정보 컬럼
#     - 실제 intro page 머문시간이 0초인 경우인듯... 나머지 컬럼 데이터가 충실함.

# %% [markdown]
# ##### 역추적용 csv 생성

# %% [markdown]
# > 인종(race), 종교(religion) 컬럼에서 '0'데이터는 따로 데이터 프레임 만듬
# csv 파일로도 저장했습니다. __(path : MACH_data/data_in_0.csv)__

# %%
df_in_0 = df[(df['TYP_out'] == 0) | (df['TYP_fight'] == 0) | (df['TYP_depnd'] == 0) | (df['TYP_anx'] == 0) | (df['TYP_try'] == 0) |
             (df['TYP_quiet'] == 0) | (df['TYP_warm'] == 0) | (df['TYP_disorg'] == 0) | (df['TYP_calm'] == 0) | (df['TYP_stable'] == 0) |
             (df['education'] == 0) | (df['urban'] == 0) | (df['gender'] == 0) | (df['engnat'] == 0) | (df['hand'] == 0)|
             (df['orientation'] == 0)| (df['married'] == 0) | (df['race'] == 0) | (df['religion'] == 0) | (df['voted'] == 0)]
df_in_0.tail()
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 73278              5.0   6.0            7.0                  1.0  11.0
# 73320              4.0  13.0           26.0                  4.0  17.0
# 73371              5.0  10.0            6.0                  5.0  11.0
# 73405              5.0  11.0           28.0                  4.0   5.0
# 73410              1.0  20.0            0.0                  4.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 73278                5.0             3.0   9.0          18.0             1.0
# 73320               25.0             2.0  10.0          38.0             3.0
# 73371                3.0             1.0   4.0           5.0             1.0
# 73405               42.0             3.0  15.0          45.0             3.0
# 73410                0.0             3.0  12.0           0.0             3.0
#
#        ...             religion   orientation   race  voted  \
# ...

# %%
df_in_0.index
# Out:
# Int64Index([   14,    27,    75,   244,   251,   289,   296,   383,   396,
#               407,
#             ...
#             73107, 73130, 73193, 73220, 73233, 73278, 73320, 73371, 73405,
#             73410],
#            dtype='int64', length=1584)

# %%
df_in_0.to_csv('./MACH_data/data_in_0.csv')

# %% [markdown]
# > 인종(race), 종교(religion) 컬럼에서 '0'데이터를 제외한
# 데이터 프레임, csv파일로 저장했습니다.

# %%
df.drop(df_in_0.index, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.tail()
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 71879              2.0  17.0           10.0                  1.0   6.0
# 71880              5.0   9.0            6.0                  5.0   4.0
# 71881              2.0  17.0            5.0                  1.0  18.0
# 71882              4.0  15.0            8.0                  3.0   9.0
# 71883              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 71879               14.0             2.0  16.0          25.0             4.0
# 71880                4.0             1.0  15.0           7.0             1.0
# 71881                7.0             1.0   9.0           5.0             1.0
# 71882                8.0             5.0  17.0           9.0             3.0
# 71883                6.0             5.0  13.0          37.0             1.0
#
#        ...             religion   orientation   race  voted  \
# ...

# %%
df['education'].value_counts()
# Out:
# High school              26478
# University degree        24288
# Graduate degree          12500
# Less than high school     7796
# 0                          822
# Name: education, dtype: int64

# %% [markdown]
# #### age (나이) 컬럼 이상치 처리

# %% [markdown]
# > - 이상치 처리 기준
#  - 기네스북 기록 기준 최고령자의 수명 : 117세 (2020년도 기준)
#  - 미국(데이터 중 46% 차지-최대비중) 기준 평균 수명 : 78.9세 (2019년도 기준)
#  - (참고) 전세계 평균 수명 : 72.6세

# %%
df['age'].plot(kind='box')

# %%
df_age = pd.DataFrame(df['age'].value_counts())
df_age.tail()
# Out:
#         age
# 476       1
# 662       1
# 87        1
# 999999    1
# 410       1

# %% [markdown]
# ##### 기네스 최대수명 기준 이상치 제거
# > 나이 117세 이상 제거

# %%
# 추가 설명 필요함.

# %%
len(df[df["age"] >118])
# Out:
# 17

# %%
df_max = df[df["age"] <=118]
df_max
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 71899              2.0  17.0           10.0                  1.0   6.0
# 71900              5.0   9.0            6.0                  5.0   4.0
# 71901              2.0  17.0            5.0                  1.0  18.0
# 71902              4.0  15.0            8.0                  3.0   9.0
# 71903              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %% [markdown]
# ##### 미국인  평균수명 기준
# >78.9세

# %%
df_1 = df[(df["age"] >78.9) & (df["age"] < 118)]
df_1
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 12                 5.0  15.0            6.0                  5.0   1.0
# 2259               5.0  10.0            6.0                  5.0   4.0
# 4093               1.0  18.0           14.0                  4.0  15.0
# 5510               1.0   6.0            5.0                  2.0   1.0
# 5582               5.0  10.0           20.0                  1.0   9.0
# 6138               1.0  15.0            5.0                  1.0  11.0
# 6685               3.0   8.0           12.0                  4.0  12.0
# 7438               3.0  13.0            0.0                  5.0   3.0
# 8160               2.0  16.0            8.0                  2.0  20.0
# 8749               4.0   6.0           12.0                  4.0   9.0
# 8752               5.0   8.0           16.0                  3.0  16.0
# 9101               1.0  12.0            6.0                  4.0  15.0
# ...

# %%
df_1['age'].plot(kind='box')

# %%
df_avg = df[df["age"] <=78.9]
df_avg

# %% [markdown]
# #### familysize (가족단위) 컬럼 이상치 처리

# %% [markdown]
# > - 이상치 처리 기준
#  - 기네스북 기록 기준 최대 가족구성원수 : 94명 (2020년도 기준)
#  - 미국(데이터 중 46% 차지-최대비중) 기준 평균 가족구성원수 : 3.14명 (2018년도 기준)
#  - (참고) 전세계 평균 가족구성원수 : 4.9명 (2019년도 기준)

# %%
df['familysize'].plot(kind='box')

# %%
df['familysize'].value_counts()
# Out:
# 2             28501
# 3             17325
# 1             10872
# 4              7430
# 5              2953
# 0              2192
# 6              1255
# 7               591
# 8               336
# 9               180
# 10               87
# 11               57
# 12               41
# 14               16
# 13               14
# 15                9
# 17                3
# 20                3
# 21                3
# 44                3
# 16                2
# 96                1
# 2147483647        1
# 999               1
# 100               1
# 67                1
# 34                1
# 2137              1
# 30                1
# 236               1
# 24                1
# 23                1
# 22                1
# 18                1
# 48                1
# Name: familysize, dtype: int64

# %% [markdown]
# ##### 기네스 최대 가족구성원 수 기준
# > familysize 94명 이상 제거

# %%
len(df[df['familysize'] > 94])
# Out:
# 6

# %%
df = df.loc[df['familysize'] <= 94]
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 71899              2.0  17.0           10.0                  1.0   6.0
# 71900              5.0   9.0            6.0                  5.0   4.0
# 71901              2.0  17.0            5.0                  1.0  18.0
# 71902              4.0  15.0            8.0                  3.0   9.0
# 71903              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %% [markdown]
# ##### 미국인 평균 가족 구성원 수 기준
# > 3.14명

# %% [markdown]
# ### EDA용 csv 생성

# %%
df.to_csv('./MACH_data/data_for_eda.csv', index=False)

# %% [markdown]
# ## sweetviz 리포트 생성

# %%
import sweetviz as sv

# %%
df_eda = pd.read_csv('./MACH_data/data_for_eda.csv')
df_eda.head()
# Out:
#    Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0              3.0   6.0           21.0                  3.0   7.0
# 1              5.0  17.0            4.0                  5.0   9.0
# 2              5.0  16.0            4.0                  5.0  12.0
# 3              2.0  12.0            9.0                  4.0   1.0
# 4              5.0  13.0            9.0                  5.0   7.0
#
#    Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  ...  \
# 0               19.0             5.0  20.0          15.0             2.0  ...
# 1                8.0             1.0  16.0           6.0             3.0  ...
# 2                3.0             1.0   2.0           7.0             1.0  ...
# 3               10.0             2.0   7.0          10.0             1.0  ...
# 4                5.0             2.0  19.0           9.0             1.0  ...
#
#                 religion   orientation   race  voted             married  \
# ...

# %%
data_rep = sv.analyze(df_eda)

# %%
data_rep.show_html('sweetviz_test.html')
# Out:
# Report sweetviz_test.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### 리포트 확인 후 컬럼 재확인 -> ```확인!!!```

# %% [markdown]
# > 1. Q_ 컬럼들에서 A는 주로 어떤질문에 어떤 답변이 많았는지 체크
# 2. age의 이상치 발견 `100세 이상 데이터 어떻게??`
# 3. race, religion의 '0' `어떻게 처리할까요??`
# 4. TYP 컬럼들에서 주로 무슨 답변을 했을지 체크
# 5. VCL 컬럼도 "신뢰성" 점수 만들어서 컬럼 하나짜리 생성 ㄱ..?
# 6. QE 답변 시간 데이터 소숫점 2자리까지 하니까 spectrum 너무 다양.. 소숫점 1자리까지 반올림 ㄱ..?

# %%
df_eda['age'].plot(kind='box')

# %%
df_eda['age'].value_counts()
# Out:
# 18     4389
# 17     3766
# 20     3541
# 21     3422
# 19     3363
#        ...
# 90        2
# 85        2
# 87        1
# 110       1
# 100       1
# Name: age, Length: 81, dtype: int64

# %%
age_value = pd.DataFrame(df_eda['age'].value_counts())
age_value
# Out:
#       age
# 18   4389
# 17   3766
# 20   3541
# 21   3422
# 19   3363
# ..    ...
# 90      2
# 85      2
# 87      1
# 110     1
# 100     1
#
# [81 rows x 1 columns]

# %%
age_value[age_value.values < 5]
# Out:
#      age
# 88     4
# 84     4
# 81     3
# 91     2
# 83     2
# 99     2
# 92     2
# 90     2
# 85     2
# 87     1
# 110    1
# 100    1

# %%
age_value[age_value.index >= 100]
# Out:
#      age
# 110    1
# 100    1

# %% [markdown]
# ### compare_intra 사용

# %% [markdown]
# > voted에서 0데이터 발견... __`임시로 no로 체크`__

# %%
df_eda['voted'].value_counts()
# Out:
# No     39651
# Yes    31669
# 0        543
# Name: voted, dtype: int64

# %%
df_eda['voted'] = df_eda['voted'].str.replace('0', "No")

# %%
df_eda['voted'].value_counts()
# Out:
# No     40194
# Yes    31669
# Name: voted, dtype: int64

# %%
cates.keys()
# Out:
# dict_keys(['education', 'urban', 'gender', 'engnat', 'hand', 'religion', 'orientation', 'race', 'voted', 'married'])

# %%
feature_config = sv.FeatureConfig(force_cat=['education', 'urban', 'gender', 'engnat', 'hand', 'religion', 'orientation', 'race', 'voted', 'married'])

# %%
comint_rep = sv.compare_intra(df_eda, df_eda['voted'] == "Yes", ["Yes", "No"])

# %%
comint_rep.show_html('sweetviz_compare_voted.html')
# Out:
# Report sweetviz_compare_voted.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## 모델

# %% [markdown]
# ### auto ml

# %%
#

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split()
