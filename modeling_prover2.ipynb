# %% [markdown]
# # 미국 데이터 iqr 2.0 기준, nan, 0 제외

# %% [markdown]
# ## age 추가

# %%
df = pd.read_csv('../MACH_data/cut_off_by_iqr.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62449              5.0   9.0            6.0                  5.0   4.0
# 62450              2.0  17.0            5.0                  1.0  18.0
# 62451              4.0  15.0            8.0                  3.0   9.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
df = df[df.country == "US"]
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 5                  4.0   4.0            9.0                  3.0   5.0
# 13                 2.0  16.0            5.0                  4.0  11.0
# 14                 4.0  14.0           10.0                  1.0   5.0
# ...                ...   ...            ...                  ...   ...
# 62429              2.0   3.0           12.0                  2.0  10.0
# 62440              4.0   2.0            5.0                  5.0   1.0
# 62442              1.0   5.0            2.0                  1.0  11.0
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %% [markdown]
# ### auto ml

# %%
from pycaret.classification import *

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = df, target = 'voted')
# Out:
# <style  type="text/css" >
# </style><table id="T_5b215036_1c3a_11eb_9041_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b215036_1c3a_11eb_9041_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5b215036_1c3a_11eb_9041_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_5b215036_1c3a_11eb_9041_acde48001122row0_col1" class="data row0 col1" >4799</td>
#             </tr>
#             <tr>
#                         <th id="T_5b215036_1c3a_11eb_9041_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5b215036_1c3a_11eb_9041_acde48001122row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
# train test 7:3
(20124 + 8625)/8625
# Out:
# 3.333217391304348

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_163afcd2_1c3b_11eb_9041_acde48001122 th {
#           text-align: left;
#     }    #T_163afcd2_1c3b_11eb_9041_acde48001122row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_163afcd2_1c3b_11eb_9041_acde48001122row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_163afcd2_1c3b_11eb_9041_acde48001122row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_163afcd2_1c3b_11eb_9041_acde48001122row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_163afcd2_1c3b_11eb_9041_acde48001122row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_163afcd2_1c3b_11eb_9041_acde48001122row0_col5 {
# ...

# %% [markdown]
# #### catboost

# %%
catboost=create_model("catboost")
# Out:
# <style  type="text/css" >
#     #T_fdd74c94_1c3b_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_fdd74c94_1c3b_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_fdd74c94_1c3b_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_fdd74c94_1c3b_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_fdd74c94_1c3b_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_fdd74c94_1c3b_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_fdd74c94_1c3b_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = catboost, plot = 'feature')

# %% [markdown]
# #### gbc

# %%
gbc=create_model("gbc")
# Out:
# <style  type="text/css" >
#     #T_6a00da4e_1c3b_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_6a00da4e_1c3b_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_6a00da4e_1c3b_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_6a00da4e_1c3b_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_6a00da4e_1c3b_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_6a00da4e_1c3b_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_6a00da4e_1c3b_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = gbc, plot = 'feature')

# %% [markdown]
# #### lightgbm

# %%
lightgbm=create_model("lightgbm")
# Out:
# <style  type="text/css" >
#     #T_3e362396_1c3c_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_3e362396_1c3c_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_3e362396_1c3c_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_3e362396_1c3c_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_3e362396_1c3c_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_3e362396_1c3c_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_3e362396_1c3c_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = lightgbm, plot = 'feature')

# %% [markdown]
# ## age 빼고

# %%
df = pd.read_csv('./MACH_data/cut_off_by_iqr.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62449              5.0   9.0            6.0                  5.0   4.0
# 62450              2.0  17.0            5.0                  1.0  18.0
# 62451              4.0  15.0            8.0                  3.0   9.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
df1 = df.drop("age", axis=1)
df1
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62449              5.0   9.0            6.0                  5.0   4.0
# 62450              2.0  17.0            5.0                  1.0  18.0
# 62451              4.0  15.0            8.0                  3.0   9.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
df1 = df1[df1.country == "US"]
df1
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 5                  4.0   4.0            9.0                  3.0   5.0
# 13                 2.0  16.0            5.0                  4.0  11.0
# 14                 4.0  14.0           10.0                  1.0   5.0
# ...                ...   ...            ...                  ...   ...
# 62429              2.0   3.0           12.0                  2.0  10.0
# 62440              4.0   2.0            5.0                  5.0   1.0
# 62442              1.0   5.0            2.0                  1.0  11.0
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %% [markdown]
# ### auto ml

# %%
from pycaret.classification import *

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = df1, target = 'voted')
# Out:
# <style  type="text/css" >
# </style><table id="T_5bd8dc7c_1c3c_11eb_9041_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5bd8dc7c_1c3c_11eb_9041_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5bd8dc7c_1c3c_11eb_9041_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_5bd8dc7c_1c3c_11eb_9041_acde48001122row0_col1" class="data row0 col1" >4097</td>
#             </tr>
#             <tr>
#                         <th id="T_5bd8dc7c_1c3c_11eb_9041_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5bd8dc7c_1c3c_11eb_9041_acde48001122row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
# train test 7:3
(20124 + 8625)/8625
# Out:
# 3.333217391304348

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_660974f6_1c33_11eb_af5c_3c6aa770c1cc th {
#           text-align: left;
# ...

# %% [markdown]
# #### catboost

# %%
catboost=create_model("catboost")
# Out:
# <style  type="text/css" >
#     #T_fa259a82_1c3c_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_fa259a82_1c3c_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_fa259a82_1c3c_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_fa259a82_1c3c_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_fa259a82_1c3c_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_fa259a82_1c3c_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_fa259a82_1c3c_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = catboost, plot = 'feature')

# %% [markdown]
# #### gbc

# %%
gbc=create_model("gbc")
# Out:
# <style  type="text/css" >
#     #T_73e6ef20_1c3c_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_73e6ef20_1c3c_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_73e6ef20_1c3c_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_73e6ef20_1c3c_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_73e6ef20_1c3c_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_73e6ef20_1c3c_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_73e6ef20_1c3c_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = gbc, plot = 'feature')

# %% [markdown]
# #### lightgbm

# %%
lightgbm=create_model("lightgbm")
# Out:
# <style  type="text/css" >
#     #T_86197514_1c3c_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_86197514_1c3c_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_86197514_1c3c_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_86197514_1c3c_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_86197514_1c3c_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_86197514_1c3c_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_86197514_1c3c_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = lightgbm, plot = 'feature')

# %% [markdown]
# ## age, Q_E, Q_I 제외한 데이터

# %%
df = pd.read_csv('./MACH_data/cut_off_by_iqr.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62449              5.0   9.0            6.0                  5.0   4.0
# 62450              2.0  17.0            5.0                  1.0  18.0
# 62451              4.0  15.0            8.0                  3.0   9.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
df1 = df.drop("age", axis=1)
df1
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62449              5.0   9.0            6.0                  5.0   4.0
# 62450              2.0  17.0            5.0                  1.0  18.0
# 62451              4.0  15.0            8.0                  3.0   9.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
df1 = df1[df1.country == "US"]
df1
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 5                  4.0   4.0            9.0                  3.0   5.0
# 13                 2.0  16.0            5.0                  4.0  11.0
# 14                 4.0  14.0           10.0                  1.0   5.0
# ...                ...   ...            ...                  ...   ...
# 62429              2.0   3.0           12.0                  2.0  10.0
# 62440              4.0   2.0            5.0                  5.0   1.0
# 62442              1.0   5.0            2.0                  1.0  11.0
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
cols = []
for i in df1.columns:
    if ('E' in i) | ('I' in i):
        cols.append(i)
cols
# Out:
# ['Q1I',
#  'Q1E_notell_2u',
#  'Q2I',
#  'Q2E_ppl_nd_dangun',
#  'Q3I',
#  'Q3E_do_moral',
#  'Q4I',
#  'Q4E_ppl_good',
#  'Q5I',
#  'Q5E_ppl_bad',
#  'Q6I',
#  'Q6E_hnsty_best',
#  'Q7I',
#  'Q7E_lying_bad',
#  'Q8I',
#  'Q8E_ppl_lazy',
#  'Q9I',
#  'Q9E_humble_hnst',
#  'Q10I',
#  'Q10E_hnstly_ask',
#  'Q11I',
#  'Q11E_leader_clean',
#  'Q12I',
#  'Q12E_trust_trouble',
#  'Q13I',
#  'Q13E_ppl_criminal',
#  'Q14I',
#  'Q14E_ppl_brave',
#  'Q15I',
#  'Q15E_abu_good',
#  'Q16I',
#  'Q16E_ppl_good',
#  'Q17I',
#  'Q17E_ppl_notbad',
#  'Q18I',
#  'Q18E_komsu_better',
#  'Q19I',
#  'Q19E_anrocksa_ok',
#  'Q20I',
#  'Q20E_money_good']

# %%
df_n_age_EI = df1.drop(cols, axis=1)

# %% [markdown]
# ### auto ML

# %%
from pycaret.classification import *

# %%
clf = setup(data = df_n_age_EI, target = 'voted', normalize=True, normalize_method = "maxabs")
# Out:
# <style  type="text/css" >
#     #T_ad9a1f00_1c67_11eb_b8f4_acde48001122row29_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_ad9a1f00_1c67_11eb_b8f4_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ad9a1f00_1c67_11eb_b8f4_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ad9a1f00_1c67_11eb_b8f4_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_ad9a1f00_1c67_11eb_b8f4_acde48001122row0_col1" class="data row0 col1" >890</td>
#             </tr>
#             <tr>
#                         <th id="T_ad9a1f00_1c67_11eb_b8f4_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models(sort='AUC')
# Out:
# <style  type="text/css" >
#     #T_562cd054_1c68_11eb_b8f4_acde48001122 th {
#           text-align: left;
#     }    #T_562cd054_1c68_11eb_b8f4_acde48001122row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_562cd054_1c68_11eb_b8f4_acde48001122row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_562cd054_1c68_11eb_b8f4_acde48001122row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_562cd054_1c68_11eb_b8f4_acde48001122row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_562cd054_1c68_11eb_b8f4_acde48001122row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_562cd054_1c68_11eb_b8f4_acde48001122row0_col5 {
# ...

# %% [markdown]
# #### catboost

# %%
def make_feature_plot(model):
    model = create_model(model)
    return plot_model(estimator = model, plot='feature')

# %%
make_feature_plot('catboost')

# %%
score_cat_iqr = pull()

# %%
score_cat_iqr.loc['Mean']['AUC']
# Out:
# 0.7839

# %% [markdown]
# #### gbc

# %%
make_feature_plot('gbc')

# %%
score_gbc_iqr = pull()
score_gbc_iqr.loc['Mean']['AUC']
# Out:
# 0.7874

# %% [markdown]
# #### lightgbm

# %%
make_feature_plot('lightgbm')

# %%
score_lightgbm_iqr = pull()
score_lightgbm_iqr.loc['Mean']['AUC']
# Out:
# 0.7858

# %% [markdown]
# #### lda (Linear Discriminant Analysis)

# %%
make_feature_plot('lda')

# %%
score_lda_iqr = pull()
score_lda_iqr.loc['Mean']['AUC']
# Out:
# 0.7844

# %%
iqr_df = []
iqr_df.append({
    'cat' : score_cat_iqr.loc["Mean"]['AUC'], 
    'gbc' : score_gbc_iqr.loc['Mean']['AUC'],
    'lightgbm' : score_lightgbm_iqr.loc['Mean']['AUC'],
    'lda' : score_lda_iqr.loc['Mean']['AUC']
})
iqr_df = pd.DataFrame(iqr_df, index=['IQR'])
iqr_df
# Out:
#         cat     gbc  lightgbm     lda
# IQR  0.7839  0.7874    0.7858  0.7844

# %% [markdown]
# # 미국 데이터 평균 수명, 평균가족, nan, 0제외

# %% [markdown]
# ## age 추가

# %%
df = pd.read_csv('../MACH_data/cut_off_by_avg_US.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  5.0  17.0            4.0                  5.0   9.0
# 1                  5.0  16.0            4.0                  5.0  12.0
# 2                  4.0   4.0            9.0                  3.0   5.0
# 3                  2.0  16.0            5.0                  4.0  11.0
# 4                  4.0  14.0           10.0                  1.0   5.0
# ...                ...   ...            ...                  ...   ...
# 23681              4.0  13.0            6.0                  4.0  19.0
# 23682              5.0  11.0            3.0                  5.0  18.0
# 23683              2.0   3.0           12.0                  2.0  10.0
# 23684              4.0   2.0            5.0                  5.0   1.0
# 23685              2.0  17.0           10.0                  1.0   6.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %% [markdown]
# ### auto ml

# %%
from pycaret.classification import *

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = df, target = 'voted')
# Out:
# <style  type="text/css" >
# </style><table id="T_91d1aed4_1c3d_11eb_9041_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_91d1aed4_1c3d_11eb_9041_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_91d1aed4_1c3d_11eb_9041_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_91d1aed4_1c3d_11eb_9041_acde48001122row0_col1" class="data row0 col1" >1062</td>
#             </tr>
#             <tr>
#                         <th id="T_91d1aed4_1c3d_11eb_9041_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_91d1aed4_1c3d_11eb_9041_acde48001122row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
# train test 7:3
(16580 + 7106)/7106
# Out:
# 3.3332395159020547

# %% [markdown]
# #### catboost

# %%
catboost=create_model("catboost")
# Out:
# <style  type="text/css" >
#     #T_12e10ce0_1c3e_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_12e10ce0_1c3e_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_12e10ce0_1c3e_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_12e10ce0_1c3e_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_12e10ce0_1c3e_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_12e10ce0_1c3e_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_12e10ce0_1c3e_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = catboost, plot = 'feature')

# %% [markdown]
# #### gbc

# %%
gbc=create_model("gbc")
# Out:
# <style  type="text/css" >
#     #T_23fa5608_1c3e_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_23fa5608_1c3e_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_23fa5608_1c3e_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_23fa5608_1c3e_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_23fa5608_1c3e_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_23fa5608_1c3e_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_23fa5608_1c3e_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = gbc, plot = 'feature')

# %% [markdown]
# #### lightgbm

# %%
lightgbm=create_model("lightgbm")
# Out:
# <style  type="text/css" >
#     #T_257c071a_1c3e_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_257c071a_1c3e_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_257c071a_1c3e_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_257c071a_1c3e_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_257c071a_1c3e_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_257c071a_1c3e_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_257c071a_1c3e_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = lightgbm, plot = 'feature')

# %% [markdown]
# ## age 빼고

# %%
df = pd.read_csv('./MACH_data/cut_off_by_avg_US.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  5.0  17.0            4.0                  5.0   9.0
# 1                  5.0  16.0            4.0                  5.0  12.0
# 2                  4.0   4.0            9.0                  3.0   5.0
# 3                  2.0  16.0            5.0                  4.0  11.0
# 4                  4.0  14.0           10.0                  1.0   5.0
# ...                ...   ...            ...                  ...   ...
# 23681              4.0  13.0            6.0                  4.0  19.0
# 23682              5.0  11.0            3.0                  5.0  18.0
# 23683              2.0   3.0           12.0                  2.0  10.0
# 23684              4.0   2.0            5.0                  5.0   1.0
# 23685              2.0  17.0           10.0                  1.0   6.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
df1 = df.drop("age", axis=1)
df1
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  5.0  17.0            4.0                  5.0   9.0
# 1                  5.0  16.0            4.0                  5.0  12.0
# 2                  4.0   4.0            9.0                  3.0   5.0
# 3                  2.0  16.0            5.0                  4.0  11.0
# 4                  4.0  14.0           10.0                  1.0   5.0
# ...                ...   ...            ...                  ...   ...
# 23681              4.0  13.0            6.0                  4.0  19.0
# 23682              5.0  11.0            3.0                  5.0  18.0
# 23683              2.0   3.0           12.0                  2.0  10.0
# 23684              4.0   2.0            5.0                  5.0   1.0
# 23685              2.0  17.0           10.0                  1.0   6.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %% [markdown]
# ### auto ml

# %%
from pycaret.classification import *

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = df1, target = 'voted')
# Out:
# <style  type="text/css" >
# </style><table id="T_58544594_1c3e_11eb_9041_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58544594_1c3e_11eb_9041_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_58544594_1c3e_11eb_9041_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_58544594_1c3e_11eb_9041_acde48001122row0_col1" class="data row0 col1" >3186</td>
#             </tr>
#             <tr>
#                         <th id="T_58544594_1c3e_11eb_9041_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_58544594_1c3e_11eb_9041_acde48001122row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
# train test 7:3
(16580 + 7106)/7106
# Out:
# 3.3332395159020547

# %% [markdown]
# #### catboost

# %%
catboost=create_model("catboost")
# Out:
# <style  type="text/css" >
#     #T_c71b3f14_1c3e_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_c71b3f14_1c3e_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_c71b3f14_1c3e_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_c71b3f14_1c3e_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_c71b3f14_1c3e_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_c71b3f14_1c3e_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_c71b3f14_1c3e_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = catboost, plot = 'feature')

# %% [markdown]
# #### gbc

# %%
gbc=create_model("gbc")
# Out:
# <style  type="text/css" >
#     #T_d6d9ef9a_1c3e_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_d6d9ef9a_1c3e_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_d6d9ef9a_1c3e_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_d6d9ef9a_1c3e_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_d6d9ef9a_1c3e_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_d6d9ef9a_1c3e_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_d6d9ef9a_1c3e_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = gbc, plot = 'feature')

# %% [markdown]
# #### lightgbm

# %%
lightgbm=create_model("lightgbm")
# Out:
# <style  type="text/css" >
#     #T_d845aa68_1c3e_11eb_9041_acde48001122row10_col0 {
#             background:  yellow;
#         }    #T_d845aa68_1c3e_11eb_9041_acde48001122row10_col1 {
#             background:  yellow;
#         }    #T_d845aa68_1c3e_11eb_9041_acde48001122row10_col2 {
#             background:  yellow;
#         }    #T_d845aa68_1c3e_11eb_9041_acde48001122row10_col3 {
#             background:  yellow;
#         }    #T_d845aa68_1c3e_11eb_9041_acde48001122row10_col4 {
#             background:  yellow;
#         }    #T_d845aa68_1c3e_11eb_9041_acde48001122row10_col5 {
#             background:  yellow;
#         }    #T_d845aa68_1c3e_11eb_9041_acde48001122row10_col6 {
#             background:  yellow;
# ...

# %%
plot_model(estimator = lightgbm, plot = 'feature')

# %% [markdown]
# ## age, Q_E, Q_I 제외한 데이터

# %% [markdown]
# ### auto ML

# %%
df = pd.read_csv('./MACH_data/cut_off_by_avg_US.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  5.0  17.0            4.0                  5.0   9.0
# 1                  5.0  16.0            4.0                  5.0  12.0
# 2                  4.0   4.0            9.0                  3.0   5.0
# 3                  2.0  16.0            5.0                  4.0  11.0
# 4                  4.0  14.0           10.0                  1.0   5.0
# ...                ...   ...            ...                  ...   ...
# 23681              4.0  13.0            6.0                  4.0  19.0
# 23682              5.0  11.0            3.0                  5.0  18.0
# 23683              2.0   3.0           12.0                  2.0  10.0
# 23684              4.0   2.0            5.0                  5.0   1.0
# 23685              2.0  17.0           10.0                  1.0   6.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
df1 = df.drop("age", axis=1)
df1
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  5.0  17.0            4.0                  5.0   9.0
# 1                  5.0  16.0            4.0                  5.0  12.0
# 2                  4.0   4.0            9.0                  3.0   5.0
# 3                  2.0  16.0            5.0                  4.0  11.0
# 4                  4.0  14.0           10.0                  1.0   5.0
# ...                ...   ...            ...                  ...   ...
# 23681              4.0  13.0            6.0                  4.0  19.0
# 23682              5.0  11.0            3.0                  5.0  18.0
# 23683              2.0   3.0           12.0                  2.0  10.0
# 23684              4.0   2.0            5.0                  5.0   1.0
# 23685              2.0  17.0           10.0                  1.0   6.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
cols = []
for i in df1.columns:
    if ('E' in i) | ('I' in i):
        cols.append(i)
cols
# Out:
# ['Q1I',
#  'Q1E_notell_2u',
#  'Q2I',
#  'Q2E_ppl_nd_dangun',
#  'Q3I',
#  'Q3E_do_moral',
#  'Q4I',
#  'Q4E_ppl_good',
#  'Q5I',
#  'Q5E_ppl_bad',
#  'Q6I',
#  'Q6E_hnsty_best',
#  'Q7I',
#  'Q7E_lying_bad',
#  'Q8I',
#  'Q8E_ppl_lazy',
#  'Q9I',
#  'Q9E_humble_hnst',
#  'Q10I',
#  'Q10E_hnstly_ask',
#  'Q11I',
#  'Q11E_leader_clean',
#  'Q12I',
#  'Q12E_trust_trouble',
#  'Q13I',
#  'Q13E_ppl_criminal',
#  'Q14I',
#  'Q14E_ppl_brave',
#  'Q15I',
#  'Q15E_abu_good',
#  'Q16I',
#  'Q16E_ppl_good',
#  'Q17I',
#  'Q17E_ppl_notbad',
#  'Q18I',
#  'Q18E_komsu_better',
#  'Q19I',
#  'Q19E_anrocksa_ok',
#  'Q20I',
#  'Q20E_money_good']

# %%
df_avg_n_age_EI = df1.drop(cols, axis=1)

# %%
from pycaret.classification import *

# %%
clf = setup(data = df_avg_n_age_EI, target = 'voted', normalize=True, normalize_method = "maxabs")
# Out:
# <style  type="text/css" >
#     #T_2b4def98_1c69_11eb_b8f4_acde48001122row29_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_2b4def98_1c69_11eb_b8f4_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b4def98_1c69_11eb_b8f4_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2b4def98_1c69_11eb_b8f4_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_2b4def98_1c69_11eb_b8f4_acde48001122row0_col1" class="data row0 col1" >2029</td>
#             </tr>
#             <tr>
#                         <th id="T_2b4def98_1c69_11eb_b8f4_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models(sort="AUC")
# Out:
# <style  type="text/css" >
#     #T_c0347afa_1c69_11eb_b8f4_acde48001122 th {
#           text-align: left;
#     }    #T_c0347afa_1c69_11eb_b8f4_acde48001122row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_c0347afa_1c69_11eb_b8f4_acde48001122row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_c0347afa_1c69_11eb_b8f4_acde48001122row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_c0347afa_1c69_11eb_b8f4_acde48001122row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_c0347afa_1c69_11eb_b8f4_acde48001122row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_c0347afa_1c69_11eb_b8f4_acde48001122row0_col5 {
# ...

# %% [markdown]
# #### catboost

# %%
make_feature_plot('catboost')

# %%
score_cat_avg = pull()
score_cat_avg.loc['Mean']['AUC']
# Out:
# 0.7915

# %% [markdown]
# #### gbc

# %%
make_feature_plot('gbc')

# %%
score_gbc_avg = pull()
score_gbc_avg.loc['Mean']['AUC']
# Out:
# 0.7938

# %% [markdown]
# #### lightgbm

# %%
make_feature_plot('lightgbm')

# %%
score_lightgbm_avg = pull()
score_lightgbm_avg.loc['Mean']['AUC']
# Out:
# 0.7918

# %% [markdown]
# #### lda(Linear Discriminant Analysis)

# %%
make_feature_plot('lda')

# %%
score_lda_avg = pull()
score_lda_avg.loc['Mean']['AUC']
# Out:
# 0.789

# %% [markdown]
# ### IQR, AVG 비교 그래프
# > not in (age, Q_E, Q_I)

# %%
avg_df = []
avg_df.append({
    'cat' : score_cat_avg.loc["Mean"]['AUC'], 
    'gbc' : score_gbc_avg.loc['Mean']['AUC'],
    'lightgbm' : score_lightgbm_avg.loc['Mean']['AUC'],
    'lda' : score_lda_avg.loc['Mean']['AUC']
})
avg_df = pd.DataFrame(avg_df, index=['AVG'])
avg_df
# Out:
#         cat     gbc  lightgbm    lda
# AVG  0.7915  0.7938    0.7918  0.789

# %%
avg_df = []
avg_df.append({
    'cat' : score_cat_avg.loc["Mean"]['AUC'], 
    'gbc' : score_gbc_avg.loc['Mean']['AUC'],
    'lightgbm' : score_lightgbm_avg.loc['Mean']['AUC'],
    'lda' : score_lda_avg.loc['Mean']['AUC']
})
avg_df = pd.DataFrame(avg_df, index=['AVG'])
avg_df
# Out:
#         cat     gbc  lightgbm     lda
# AVG  0.7872  0.7886    0.7838  0.7853

# %%
avg_iqr_df = pd.concat([avg_df, iqr_df])
avg_iqr_df
# Out:
#         cat     gbc  lightgbm     lda
# AVG  0.7915  0.7938    0.7918  0.7890
# IQR  0.7839  0.7874    0.7858  0.7844

# %%
avg_iqr_df.plot(kind='bar')

# %%
avg_iqr_df.plot(kind='bar', ylim=(0.76,0.8))

# %%
avg_iqr_df.to_csv('./MACH_data/avg_iqr_df.csv')

# %% [markdown]
# # 전체국가 iqr 2.0 기준, nan, 0 제외

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../MACH_data/cut_off_by_iqr.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 62448              2.0  17.0           10.0                  1.0   6.0
# 62449              5.0   9.0            6.0                  5.0   4.0
# 62450              2.0  17.0            5.0                  1.0  18.0
# 62451              4.0  15.0            8.0                  3.0   9.0
# 62452              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
auto_train, auto_test = train_test_split(df, test_size=0.2,
                                          random_state=13)

# %%
auto_train.shape, auto_test.shape
# Out:
# ((49962, 108), (12491, 108))

# %% [markdown]
# ### auto ml

# %%
from pycaret.classification import *

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = auto_train, target = 'voted')
# Out:
# <style  type="text/css" >
# </style><table id="T_b4549dac_1c1b_11eb_a2f5_3c6aa770c1cc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4549dac_1c1b_11eb_a2f5_3c6aa770c1cclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b4549dac_1c1b_11eb_a2f5_3c6aa770c1ccrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_b4549dac_1c1b_11eb_a2f5_3c6aa770c1ccrow0_col1" class="data row0 col1" >4905</td>
#             </tr>
#             <tr>
#                         <th id="T_b4549dac_1c1b_11eb_a2f5_3c6aa770c1cclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b4549dac_1c1b_11eb_a2f5_3c6aa770c1ccrow1_col0" class="data row1 col0" >Target</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_2f4edb58_1c20_11eb_8c81_3c6aa770c1cc th {
#           text-align: left;
# ...

# %% [markdown]
# #### 모델 3선택

# %%
lightgbm=create_model("lightgbm")
# Out:
# <style  type="text/css" >
# #T_8efcfe2e_1c20_11eb_b9b9_3c6aa770c1ccrow10_col0,#T_8efcfe2e_1c20_11eb_b9b9_3c6aa770c1ccrow10_col1,#T_8efcfe2e_1c20_11eb_b9b9_3c6aa770c1ccrow10_col2,#T_8efcfe2e_1c20_11eb_b9b9_3c6aa770c1ccrow10_col3,#T_8efcfe2e_1c20_11eb_b9b9_3c6aa770c1ccrow10_col4,#T_8efcfe2e_1c20_11eb_b9b9_3c6aa770c1ccrow10_col5,#T_8efcfe2e_1c20_11eb_b9b9_3c6aa770c1ccrow10_col6{
#             background:  yellow;
#         }</style><table id="T_8efcfe2e_1c20_11eb_b9b9_3c6aa770c1cc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
lightgbm()
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=4905, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
catboost=create_model("catboost")
# Out:
# <style  type="text/css" >
# #T_8a7e5ee8_1b70_11eb_aa24_3e22fbee6a4crow10_col0,#T_8a7e5ee8_1b70_11eb_aa24_3e22fbee6a4crow10_col1,#T_8a7e5ee8_1b70_11eb_aa24_3e22fbee6a4crow10_col2,#T_8a7e5ee8_1b70_11eb_aa24_3e22fbee6a4crow10_col3,#T_8a7e5ee8_1b70_11eb_aa24_3e22fbee6a4crow10_col4,#T_8a7e5ee8_1b70_11eb_aa24_3e22fbee6a4crow10_col5,#T_8a7e5ee8_1b70_11eb_aa24_3e22fbee6a4crow10_col6{
#             background:  yellow;
#         }</style><table id="T_8a7e5ee8_1b70_11eb_aa24_3e22fbee6a4c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
gbc=create_model("gbc")
# Out:
# <style  type="text/css" >
# #T_009a9678_1b71_11eb_aa24_3e22fbee6a4crow10_col0,#T_009a9678_1b71_11eb_aa24_3e22fbee6a4crow10_col1,#T_009a9678_1b71_11eb_aa24_3e22fbee6a4crow10_col2,#T_009a9678_1b71_11eb_aa24_3e22fbee6a4crow10_col3,#T_009a9678_1b71_11eb_aa24_3e22fbee6a4crow10_col4,#T_009a9678_1b71_11eb_aa24_3e22fbee6a4crow10_col5,#T_009a9678_1b71_11eb_aa24_3e22fbee6a4crow10_col6{
#             background:  yellow;
#         }</style><table id="T_009a9678_1b71_11eb_aa24_3e22fbee6a4c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# #### 모델 튜닝

# %%
tuned_lightgbm = tune_model(lightgbm)
# Out:
# <style  type="text/css" >
# #T_3bed0148_1b71_11eb_aa24_3e22fbee6a4crow10_col0,#T_3bed0148_1b71_11eb_aa24_3e22fbee6a4crow10_col1,#T_3bed0148_1b71_11eb_aa24_3e22fbee6a4crow10_col2,#T_3bed0148_1b71_11eb_aa24_3e22fbee6a4crow10_col3,#T_3bed0148_1b71_11eb_aa24_3e22fbee6a4crow10_col4,#T_3bed0148_1b71_11eb_aa24_3e22fbee6a4crow10_col5,#T_3bed0148_1b71_11eb_aa24_3e22fbee6a4crow10_col6{
#             background:  yellow;
#         }</style><table id="T_3bed0148_1b71_11eb_aa24_3e22fbee6a4c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tuned_catboost = tune_model(catboost)
# Out:
# <style  type="text/css" >
# #T_282f4c00_1b72_11eb_aa24_3e22fbee6a4crow10_col0,#T_282f4c00_1b72_11eb_aa24_3e22fbee6a4crow10_col1,#T_282f4c00_1b72_11eb_aa24_3e22fbee6a4crow10_col2,#T_282f4c00_1b72_11eb_aa24_3e22fbee6a4crow10_col3,#T_282f4c00_1b72_11eb_aa24_3e22fbee6a4crow10_col4,#T_282f4c00_1b72_11eb_aa24_3e22fbee6a4crow10_col5,#T_282f4c00_1b72_11eb_aa24_3e22fbee6a4crow10_col6{
#             background:  yellow;
#         }</style><table id="T_282f4c00_1b72_11eb_aa24_3e22fbee6a4c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tuned_gbc = tune_model(gbc)
# Out:
# <style  type="text/css" >
# #T_0875a368_1b73_11eb_aa24_3e22fbee6a4crow10_col0,#T_0875a368_1b73_11eb_aa24_3e22fbee6a4crow10_col1,#T_0875a368_1b73_11eb_aa24_3e22fbee6a4crow10_col2,#T_0875a368_1b73_11eb_aa24_3e22fbee6a4crow10_col3,#T_0875a368_1b73_11eb_aa24_3e22fbee6a4crow10_col4,#T_0875a368_1b73_11eb_aa24_3e22fbee6a4crow10_col5,#T_0875a368_1b73_11eb_aa24_3e22fbee6a4crow10_col6{
#             background:  yellow;
#         }</style><table id="T_0875a368_1b73_11eb_aa24_3e22fbee6a4c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# #### auc그래프

# %%
plot_model(estimator = tuned_lightgbm, plot = 'auc')
# plot_model(estimator = tuned_lightgbm, plot = 'confusion_matrix')

# %%
# plot_model(estimator = tuned_catboost, plot = 'auc')
plot_model(estimator = tuned_catboost, plot = 'confusion_matrix')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Estimator Error): CatBoost estimator is not compatible with plot_model function, try using Catboost with interpret_model instead.

# %%
plot_model(estimator = tuned_gbc, plot = 'auc')
# plot_model(estimator = tuned_gbc, plot = 'confusion_matrix')

# %% [markdown]
# #### feature importance

# %%
plot_model(estimator = lightgbm, plot = 'feature')

# %%
plot_model(estimator = tuned_catboost, plot = 'feature')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Estimator Error): CatBoost estimator is not compatible with plot_model function, try using Catboost with interpret_model instead.

# %%
plot_model(estimator = tuned_gbc, plot = 'feature')

# %% [markdown]
# #### 모델평가

# %%
evaluate_model(lightgbm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-acdea57a2469> in <module>
# ----> 1 translate_model(tuned_catboost)
#
# NameError: name 'translate_model' is not defined

# %%
evaluate_model(tuned_catboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(tuned_gbc)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### best 3뽑기

# %%
best_3 = compare_models(sort = 'AUC', n_select = 3)
# Out:
# <style  type="text/css" >
#     #T_7016168c_1b6a_11eb_aa24_3e22fbee6a4c th {
#           text-align: left;
# ...

# %%
best_3
# Out:
# ...
#  GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                             learning_rate=0.1, loss='deviance', max_depth=3,
#                             max_features=None, max_leaf_nodes=None,
#                             min_impurity_decrease=0.0, min_impurity_split=None,
#                             min_samples_leaf=1, min_samples_split=2,
#                             min_weight_fraction_leaf=0.0, n_estimators=100,
#                             n_iter_no_change=None, presort='deprecated',
#                             random_state=2886, subsample=1.0, tol=0.0001,
#                             validation_fraction=0.1, verbose=0,
#                             warm_start=False),
#  LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                 importance_type='split', learning_rate=0.1, max_depth=-1,
#                 min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
# ...

# %%
best_3[0]

# %%
tuned_adaboost = tune_model(catboost)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-234eb543d66a> in <module>
# ----> 1 tuned_adaboost = tune_model(catboost)
#
# NameError: name 'catboost' is not defined

# %% [markdown]
# ### automl 앙상블

# %%
blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
# Out:
# <style  type="text/css" >
# #T_cce5817c_1b6a_11eb_aa24_3e22fbee6a4crow5_col0,#T_cce5817c_1b6a_11eb_aa24_3e22fbee6a4crow5_col1,#T_cce5817c_1b6a_11eb_aa24_3e22fbee6a4crow5_col2,#T_cce5817c_1b6a_11eb_aa24_3e22fbee6a4crow5_col3,#T_cce5817c_1b6a_11eb_aa24_3e22fbee6a4crow5_col4,#T_cce5817c_1b6a_11eb_aa24_3e22fbee6a4crow5_col5,#T_cce5817c_1b6a_11eb_aa24_3e22fbee6a4crow5_col6{
#             background:  yellow;
#         }</style><table id="T_cce5817c_1b6a_11eb_aa24_3e22fbee6a4c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
pred_holdout = predict_model(blended)
# Out:
#                Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Voting Classifier     0.721  0.8043  0.6767  0.6233  0.6489  0.4181  0.4191

# %%
final_model = finalize_model(blended)

# %%
predictions = predict_model(final_model, data = auto_test)

# %%
predictions.isnull().sum()
# Out:
# Q1_TP_notell_2u        7349
# Q1I                    7349
# Q1E_notell_2u          7349
# Q2_TP_ppl_nd_dangun    7349
# Q2I                    7349
#                        ...
# v_score                7349
# t_score                7349
# m_score                7349
# Label                  7349
# Score                  7349
# Length: 110, dtype: int64

# %%
predictions
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  NaN   NaN            NaN                  NaN   NaN
# 1                  NaN   NaN            NaN                  NaN   NaN
# 2                  NaN   NaN            NaN                  NaN   NaN
# 3                  NaN   NaN            NaN                  NaN   NaN
# 4                  NaN   NaN            NaN                  NaN   NaN
# ...                ...   ...            ...                  ...   ...
# 45806              5.0  11.0            9.0                  3.0   3.0
# 45807              3.0  20.0            3.0                  4.0  12.0
# 45821              2.0  20.0            6.0                  3.0  14.0
# 45825              4.0   7.0           16.0                  5.0  16.0
# 45830              2.0  17.0           10.0                  1.0   6.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...
