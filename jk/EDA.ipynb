# %%
df = pd.read_csv('./data/MACH_data/data.csv', delimiter='\t')
df
# Out:
#        Q1A   Q1I      Q1E  Q2A   Q2I      Q2E  Q3A   Q3I      Q3E  Q4A  ...  \
# 0      3.0   6.0  21017.0  3.0   7.0  18600.0  5.0  20.0  14957.0  2.0  ...
# 1      5.0  17.0   3818.0  5.0   9.0   7850.0  1.0  16.0   5902.0  3.0  ...
# 2      5.0  16.0   4186.0  5.0  12.0   2900.0  1.0   2.0   7160.0  1.0  ...
# 3      2.0  12.0   9373.0  4.0   1.0  10171.0  2.0   7.0  10117.0  1.0  ...
# 4      5.0  13.0   9465.0  5.0   7.0   5284.0  2.0  19.0   8872.0  1.0  ...
# ...    ...   ...      ...  ...   ...      ...  ...   ...      ...  ...  ...
# 73484  2.0  17.0   9925.0  1.0   6.0  14218.0  2.0  16.0  25499.0  4.0  ...
# 73485  5.0   9.0   5816.0  5.0   4.0   4368.0  1.0  15.0   7246.0  1.0  ...
# 73486  2.0  17.0   5353.0  1.0  18.0   6846.0  1.0   9.0   4920.0  1.0  ...
# 73487  4.0  15.0   7974.0  3.0   9.0   7901.0  5.0  17.0   8647.0  3.0  ...
# 73488  3.0  12.0   7567.0  1.0  10.0   5766.0  5.0  13.0  37103.0  1.0  ...
#
#        screenw  screenh  hand  religion  orientation  race  voted  married  \
# 0       1440.0    900.0     1         7            1    30      1        2
# 1       1536.0    864.0     1         1            1    60      2        1
# 2        375.0    667.0     1         2            2    10      2        1
# 3       1280.0    720.0     1         6            1    60      1        3
# 4        360.0    640.0     1         4            3    60      1        1
# ...        ...      ...   ...       ...          ...   ...    ...      ...
# 73484   2048.0   1080.0     1        12            1    10      2        2
# 73485   1440.0    900.0     1         2            3    60      2        1
# 73486   1280.0   1024.0     1         1            1    60      2        1
# 73487    414.0    736.0     1         3            1    10      1        1
# 73488   1366.0    768.0     1         4            1    70      2        1
#
#        familysize                    major
# 0               5               Marketing
# 1               2              mathematics
# 2               2                Chemistry
# 3               2  international relations
# 4               2               Management
# ...           ...                      ...
# 73484           1                 business
# 73485           2                sociology
# 73486           3                      NaN
# 73487           4                 Business
# 73488           4                      NaN
#
# [73489 rows x 105 columns]

# %%
df.columns
# Out:
# Index(['Q1A', 'Q1I', 'Q1E', 'Q2A', 'Q2I', 'Q2E', 'Q3A', 'Q3I', 'Q3E', 'Q4A',
#        ...
#        'screenw', 'screenh', 'hand', 'religion', 'orientation', 'race',
#        'voted', 'married', 'familysize', 'major'],
#       dtype='object', length=105)

# %%
df['urban'] = df['urban'].astype('str')

# %%
df['urban'] = df['urban'].str.replace('1', 'Rural')
df['urban'] = df['urban'].str.replace('2', 'Suburban')
df['urban'] = df['urban'].str.replace('3', 'Urban')

# %%
df['urban']
# Out:
# 0           Urban
# 1        Suburban
# 2           Rural
# 3           Urban
# 4        Suburban
#            ...
# 73484       Urban
# 73485    Suburban
# 73486       Urban
# 73487       Urban
# 73488       Urban
# Name: urban, Length: 73489, dtype: object

# %%
# urban
df[df['urban'] == 1] = 'Rural'
df[df['urban'] == 2] = 'Suburban'
df[df['urban'] == 3] = 'Urban'

# %%
# gender
df[df['urban'] == 1] = 'Male'
df[df['urban'] == 2] = 'Female'
df[df['urban'] == 3] = 'Other'

# %%
# engnat
df[df['engnat'] == 1] = 'Yes'
df[df['engnat'] == 2] = 'No'

# %%
df
# Out:
#                          Q1A                    Q1I                    Q1E  \
# 0                High school            High school            High school
# 1                High school            High school            High school
# 2      Less than high school  Less than high school  Less than high school
# 3          University degree      University degree      University degree
# 4                High school            High school            High school
# ...                      ...                    ...                    ...
# 73484      University degree      University degree      University degree
# 73485            High school            High school            High school
# 73486            High school            High school            High school
# 73487            High school            High school            High school
# 73488            High school            High school            High school
#
#                          Q2A                    Q2I                    Q2E  \
# 0                High school            High school            High school
# 1                High school            High school            High school
# 2      Less than high school  Less than high school  Less than high school
# 3          University degree      University degree      University degree
# 4                High school            High school            High school
# ...                      ...                    ...                    ...
# 73484      University degree      University degree      University degree
# 73485            High school            High school            High school
# 73486            High school            High school            High school
# 73487            High school            High school            High school
# 73488            High school            High school            High school
#
#                          Q3A                    Q3I                    Q3E  \
# 0                High school            High school            High school
# 1                High school            High school            High school
# 2      Less than high school  Less than high school  Less than high school
# 3          University degree      University degree      University degree
# 4                High school            High school            High school
# ...                      ...                    ...                    ...
# 73484      University degree      University degree      University degree
# 73485            High school            High school            High school
# 73486            High school            High school            High school
# 73487            High school            High school            High school
# 73488            High school            High school            High school
#
#                          Q4A  ...                screenh  \
# 0                High school  ...            High school
# 1                High school  ...            High school
# 2      Less than high school  ...  Less than high school
# 3          University degree  ...      University degree
# 4                High school  ...            High school
# ...                      ...  ...                    ...
# 73484      University degree  ...      University degree
# 73485            High school  ...            High school
# 73486            High school  ...            High school
# 73487            High school  ...            High school
# 73488            High school  ...            High school
#
#                         hand               religion            orientation  \
# 0                High school            High school            High school
# 1                High school            High school            High school
# 2      Less than high school  Less than high school  Less than high school
# 3          University degree      University degree      University degree
# 4                High school            High school            High school
# ...                      ...                    ...                    ...
# 73484      University degree      University degree      University degree
# 73485            High school            High school            High school
# 73486            High school            High school            High school
# 73487            High school            High school            High school
# 73488            High school            High school            High school
#
#                         race                  voted                married  \
# 0                High school            High school            High school
# 1                High school            High school            High school
# 2      Less than high school  Less than high school  Less than high school
# 3          University degree      University degree      University degree
# 4                High school            High school            High school
# ...                      ...                    ...                    ...
# 73484      University degree      University degree      University degree
# 73485            High school            High school            High school
# 73486            High school            High school            High school
# 73487            High school            High school            High school
# 73488            High school            High school            High school
#
#                   familysize                  major                major_l
# 0                High school            High school            High school
# 1                High school            High school            High school
# 2      Less than high school  Less than high school  Less than high school
# 3          University degree      University degree      University degree
# 4                High school            High school            High school
# ...                      ...                    ...                    ...
# 73484      University degree      University degree      University degree
# 73485            High school            High school            High school
# 73486            High school            High school            High school
# 73487            High school            High school            High school
# 73488            High school            High school            High school
#
# [73489 rows x 106 columns]

# %%
df['country'].value_counts().plot(kind='pie')

# %%
df['engnat'].value_counts().plot(kind='pie')

# %%
import matplotlib.pyplot as plt

# %%
df['education'].value_counts().plot(kind='pie', autopct="%.1f%%", 
                                    labels=['High school', 'University degree', 'Graduate degree', 'Less than high school', 'None'])
plt.ylabel('');

# %%
pd.DataFrame(df['major'].value_counts())
# Out:
#                                                major
# Psychology                                      1655
# Business                                        1328
# English                                         1200
# psychology                                      1196
# Engineering                                      889
# ...                                              ...
# Business Innovation                                1
# Business communications                            1
# I will attend law school                           1
# Graphic design and minor in architecture, and      1
# Accountacy                                         1
#
# [8938 rows x 1 columns]

# %%
df['major_l'] = df['major'].str.lower()

# %%
df['major_l'] = df['major_l'].str.strip()

# %%
df['major_l'].value_counts()
# Out:
# psychology                        3601
# business                          2042
# engineering                       1836
# english                           1577
# computer science                  1479
#                                   ...
# admnistration                        1
# pharmaceuticals                      1
# economics & mandarin (chinese)       1
# arts & creative technology           1
# chiropractic                         1
# Name: major_l, Length: 6686, dtype: int64

# %%
df_1 = pd.DataFrame(df['major_l'].value_counts())
df_1[df_1['major_l']== 1]
# Out:
#                                    major_l
# wildlife-management                      1
# machinery                                1
# physics or chemistry                     1
# physical education/coaching              1
# management science and technology        1
# ...                                    ...
# admnistration                            1
# pharmaceuticals                          1
# economics & mandarin (chinese)           1
# arts & creative technology               1
# chiropractic                             1
#
# [5182 rows x 1 columns]

# %%
df['familysize'].value_counts()
# Out:
# 2             29069
# 3             17691
# 1             11090
# 4              7617
# 5              3052
# 0              2264
# 6              1292
# 7               619
# 8               344
# 9               185
# 10               94
# 11               60
# 12               41
# 14               16
# 13               15
# 15               10
# 17                3
# 44                3
# 20                3
# 21                3
# 16                3
# 96                1
# 2147483647        1
# 999               1
# 100               1
# 67                1
# 34                1
# 2137              1
# 30                1
# 24                1
# 900000            1
# 23                1
# 22                1
# 18                1
# 236               1
# 48                1
# Name: familysize, dtype: int64

# %%
df['Q1A'].value_counts()
# Out:
# 5.0    22539
# 4.0    16463
# 1.0    14150
# 2.0    11911
# 3.0     8423
# Name: Q1A, dtype: int64

# %%
df_1 = df[df['voted'] == 2]

# %%
df_1['education'].value_counts()
# Out:
# 2    17310
# 3    10336
# 1     7475
# 4     5034
# 0      459
# Name: education, dtype: int64

# %%
import sweetviz as sv
