# %%
import matplotlib.pyplot as plt
import seaborn as sns
import hangul_font
# %matplotlib inline
# Out:
# Hangul font is set!

# %%
df = pd.read_csv('../MACH_data/raw_data_for_EDA.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 2                  5.0  16.0            4.0                  5.0  12.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# ...                ...   ...            ...                  ...   ...
# 73484              2.0  17.0           10.0                  1.0   6.0
# 73485              5.0   9.0            6.0                  5.0   4.0
# 73486              2.0  17.0            5.0                  1.0  18.0
# 73487              4.0  15.0            8.0                  3.0   9.0
# 73488              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 0                   19.0             5.0  20.0          15.0             2.0
# 1                    8.0             1.0  16.0           6.0             3.0
# 2                    3.0             1.0   2.0           7.0             1.0
# 3                   10.0             2.0   7.0          10.0             1.0
# 4                    5.0             2.0  19.0           9.0             1.0
# ...                  ...             ...   ...           ...             ...
# 73484               14.0             2.0  16.0          25.0             4.0
# 73485                4.0             1.0  15.0           7.0             1.0
# 73486                7.0             1.0   9.0           5.0             1.0
# 73487                8.0             5.0  17.0           9.0             3.0
# 73488                6.0             5.0  13.0          37.0             1.0
#
#        ...   orientation   race  voted             married  familysize  \
# 0      ...  Heterosexual  Black    Yes   Currently married           5
# 1      ...  Heterosexual  White     No       Never married           2
# 2      ...      Bisexual  Asian     No       Never married           2
# 3      ...  Heterosexual  White    Yes  Previously married           2
# 4      ...    Homosexual  White    Yes       Never married           2
# ...    ...           ...    ...    ...                 ...         ...
# 73484  ...  Heterosexual  Asian     No   Currently married           1
# 73485  ...    Homosexual  White     No       Never married           2
# 73486  ...  Heterosexual  White     No       Never married           3
# 73487  ...  Heterosexual  Asian    Yes       Never married           4
# 73488  ...  Heterosexual  Other     No       Never married           4
#
#                          major  score  v_score  t_score  m_score
# 0                   Marketing    75.0     35.0     33.0      7.0
# 1                  mathematics   91.0     37.0     45.0      9.0
# 2                    Chemistry   98.0     43.0     45.0     10.0
# 3      international relations   78.0     37.0     36.0      5.0
# 4                   Management   85.0     35.0     41.0      9.0
# ...                        ...    ...      ...      ...      ...
# 73484                 business   59.0     28.0     26.0      5.0
# 73485                sociology   90.0     37.0     43.0     10.0
# 73486                      NaN   69.0     34.0     27.0      8.0
# 73487                 Business   53.0     25.0     22.0      6.0
# 73488                      NaN   64.0     36.0     23.0      5.0
#
# [73489 rows x 109 columns]

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x=df['voted']);

# %%
df=df[df['age']>17]

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x=df['voted']);

# %% [markdown]
# ### QA

# %%
col_list = list(df.columns)
pos_col = []
neg_col = []

for col in col_list:
    if "P" in col and "Y" not in col:
        pos_col.append(col)
    if "N" in col:
        neg_col.append(col)
        
print(pos_col, '\n', '\n', neg_col)
# Out:
# ['Q1_TP_notell_2u', 'Q2_TP_ppl_nd_dangun', 'Q5_VP_ppl_bad', 'Q8_VP_ppl_lazy', 'Q12_TP_trust_trouble', 'Q13_VP_ppl_criminal', 'Q15_TP_abu_good', 'Q18_VP_komsu_better', 'Q19_MP_anrocksa_ok', 'Q20_VP_money_good']
#
#  ['Q3_TN_do_moral', 'Q4_VN_ppl_good', 'Q6_TN_hnsty_best', 'Q7_TN_lying_bad', 'Q9_MN_humble_hnst', 'Q10_TN_hnstly_ask', 'Q11_VN_leader_clean', 'Q14_VN_ppl_brave', 'Q16_TN_ppl_good', 'Q17_VN_ppl_notbad']

# %% [markdown]
# #### all

# %%
figure, ((ax1,ax2,ax3,ax4,ax5), (ax6,ax7,ax8,ax9,ax10), (ax11, ax12, ax13, ax14, ax15), (ax16, ax17, ax18, ax19, ax20)) = plt.subplots(nrows=4, ncols=5)
figure.set_size_inches(20,16)

for n, c in enumerate(pos_col):
    ax = globals()["ax" + '{}'.format(n+1)]
    plt.figure(figsize=(4, 4))
    plt.xticks([1, 2, 3, 4, 5])
    
    plt_ = sns.histplot(df, x=c, hue='voted', binwidth=0.5, ax=ax)
    plt_.set(ylabel="", ylim=(0, 22000))

for n, c in enumerate(neg_col):
    ax = globals()["ax" + '{}'.format(n+11)]
    plt.figure(figsize=(4, 4))
    plt.xticks([1, 2, 3, 4, 5])
    
    plt_= sns.histplot(df, x=c, hue='voted', binwidth=0.5, ax=ax)
    plt_.set(ylabel="", ylim=(0, 22000))
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   app.launch_new_instance()

# %% [markdown]
# #### Q18 +

# %%
plt.figure(figsize=(4, 4))
plt.yticks([0, 5000, 10000, 15000, 20000, 25000])
plt.xticks([1, 2, 3, 4, 5])
a_plot = sns.histplot(df, x='Q18_VP_komsu_better', hue='voted', binwidth=0.5)
a_plot.set(ylim=(0, 19000))
# Out:
# [(0, 19000)]

# %% [markdown]
# #### Q11 -

# %%
plt.figure(figsize=(4, 4))
plt.yticks([0, 5000, 10000, 15000, 20000, 25000])
plt.xticks([1, 2, 3, 4, 5])
b_plot = sns.histplot(df, x='Q11_VN_leader_clean', hue='voted', binwidth=0.5)
b_plot.set(ylim=(0, 19000))
# Out:
# [(0, 19000)]

# %% [markdown]
# #### score

# %%
plt.figure(figsize=(10, 4))
sns.histplot(df, x='score', hue='voted')

# %%
df["score"].describe()
# Out:
# count    61968.000000
# mean        67.053544
# std         15.846922
# min          0.000000
# 25%         55.000000
# 50%         68.000000
# 75%         79.000000
# max        100.000000
# Name: score, dtype: float64

# %%
len(df[df["score"]<50])/len(df)
# Out:
# 0.15332106893880712

# %% [markdown]
# ### QI

# %%
col_list = list(df.columns)
i_col = []

for col in col_list:
    if "I" in col and "Y" not in col:
        i_col.append(col)
print(i_col)
# Out:
# ['Q1I', 'Q2I', 'Q3I', 'Q4I', 'Q5I', 'Q6I', 'Q7I', 'Q8I', 'Q9I', 'Q10I', 'Q11I', 'Q12I', 'Q13I', 'Q14I', 'Q15I', 'Q16I', 'Q17I', 'Q18I', 'Q19I', 'Q20I']

# %%
figure, ((ax1,ax2,ax3,ax4,ax5), (ax6,ax7,ax8,ax9,ax10), (ax11, ax12, ax13, ax14, ax15), (ax16, ax17, ax18, ax19, ax20)) = plt.subplots(nrows=4, ncols=5)
figure.set_size_inches(20,16)

for n, c in enumerate(i_col):
    ax = globals()["ax" + '{}'.format(n+1)]
    plt.figure(figsize=(4, 4))
    plt.xticks([1, 2, 3, 4, 5])
    
    plt_ = sns.histplot(df, x=c, hue='voted', binwidth=0.5, ax=ax, legend=False)
    plt_.set(ylabel="", ylim=(0, 1750))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# ### QE

# %%
e_cols = []
for i in df.columns:
    if  "E" in i :
        e_cols.append(i)
e_cols
# Out:
# ['Q1E_notell_2u',
#  'Q2E_ppl_nd_dangun',
#  'Q3E_do_moral',
#  'Q4E_ppl_good',
#  'Q5E_ppl_bad',
#  'Q6E_hnsty_best',
#  'Q7E_lying_bad',
#  'Q8E_ppl_lazy',
#  'Q9E_humble_hnst',
#  'Q10E_hnstly_ask',
#  'Q11E_leader_clean',
#  'Q12E_trust_trouble',
#  'Q13E_ppl_criminal',
#  'Q14E_ppl_brave',
#  'Q15E_abu_good',
#  'Q16E_ppl_good',
#  'Q17E_ppl_notbad',
#  'Q18E_komsu_better',
#  'Q19E_anrocksa_ok',
#  'Q20E_money_good']

# %%
df_QE = df[e_cols]
df_QE
# Out:
#        Q1E_notell_2u  Q2E_ppl_nd_dangun  Q3E_do_moral  Q4E_ppl_good  \
# 0               21.0               19.0          15.0          12.0
# 1                4.0                8.0           6.0           6.0
# 2                4.0                3.0           7.0           3.0
# 3                9.0               10.0          10.0           4.0
# 4                9.0                5.0           9.0           4.0
# ...              ...                ...           ...           ...
# 73484           10.0               14.0          25.0          13.0
# 73485            6.0                4.0           7.0           5.0
# 73486            5.0                7.0           5.0           4.0
# 73487            8.0                8.0           9.0          13.0
# 73488            8.0                6.0          37.0           3.0
#
#        Q5E_ppl_bad  Q6E_hnsty_best  Q7E_lying_bad  Q8E_ppl_lazy  \
# 0             21.0             8.0           11.0          10.0
# 1              7.0             3.0           11.0           5.0
# 2              6.0             2.0            4.0           5.0
# 3             17.0             5.0            6.0           6.0
# 4             32.0             8.0           20.0          10.0
# ...            ...             ...            ...           ...
# 73484         46.0            20.0           31.0          20.0
# 73485         10.0             5.0            5.0          13.0
# 73486          6.0             4.0            4.0           4.0
# 73487         14.0             5.0           13.0          12.0
# 73488          9.0             3.0            4.0           6.0
#
#        Q9E_humble_hnst  Q10E_hnstly_ask  Q11E_leader_clean  \
# 0                 22.0             36.0               11.0
# 1                 16.0              9.0                4.0
# 2                  4.0             11.0                7.0
# 3                 11.0             17.0                7.0
# 4                 10.0             14.0                9.0
# ...                ...              ...                ...
# 73484             24.0             30.0               29.0
# 73485              7.0             15.0                5.0
# 73486              5.0              7.0                6.0
# 73487              9.0             46.0               20.0
# 73488             10.0             13.0                7.0
#
#        Q12E_trust_trouble  Q13E_ppl_criminal  Q14E_ppl_brave  Q15E_abu_good  \
# 0                    11.0               16.0            11.0            7.0
# 1                     3.0                6.0             6.0            4.0
# 2                     3.0                5.0             4.0            4.0
# 3                     7.0               15.0             3.0            6.0
# 4                    16.0               24.0             7.0            6.0
# ...                   ...                ...             ...            ...
# 73484                 7.0               20.0            15.0           19.0
# 73485                 4.0               15.0             5.0            3.0
# 73486                 4.0                9.0             2.0            4.0
# 73487                 8.0               12.0             5.0           23.0
# 73488                 5.0               11.0             1.0            5.0
#
#        Q16E_ppl_good  Q17E_ppl_notbad  Q18E_komsu_better  Q19E_anrocksa_ok  \
# 0               10.0             26.0               10.0              14.0
# 1                5.0              8.0                4.0              14.0
# 2                3.0             32.0                3.0               4.0
# 3                5.0             18.0                7.0              13.0
# 4                5.0             24.0                7.0              11.0
# ...              ...              ...                ...               ...
# 73484            6.0             47.0               17.0              62.0
# 73485            8.0            147.0                4.0              12.0
# 73486            5.0              4.0                3.0               9.0
# 73487           10.0             14.0                7.0               9.0
# 73488            6.0             16.0               10.0              10.0
#
#        Q20E_money_good
# 0                 36.0
# 1                 13.0
# 2                  8.0
# 3                 14.0
# 4                 22.0
# ...                ...
# 73484             38.0
# 73485             15.0
# 73486             12.0
# 73487              1.0
# 73488             18.0
#
# [73489 rows x 20 columns]

# %%
df_QE.describe().T.plot(kind='line')

# %%
df_QE.describe()
# Out:
#        Q1E_notell_2u  Q2E_ppl_nd_dangun   Q3E_do_moral  Q4E_ppl_good  \
# count   61966.000000       61966.000000   61966.000000  61966.000000
# mean       12.925023          10.975712      17.854775      8.119937
# std       153.633349         108.834743     925.173428    111.209391
# min         0.000000           0.000000       0.000000     -5.000000
# 25%         5.000000           5.000000       6.000000      3.000000
# 50%         7.000000           6.000000       8.000000      5.000000
# 75%        11.000000          10.000000      12.000000      7.000000
# max     32310.000000       14948.000000  221153.000000  19766.000000
#
#         Q5E_ppl_bad  Q6E_hnsty_best  Q7E_lying_bad  Q8E_ppl_lazy  \
# count  61966.000000    61966.000000   61966.000000  61966.000000
# mean      20.933980        7.055240      11.033389     10.789804
# std      492.997124       40.550745     377.038468     65.433093
# min        0.000000        0.000000      -2.000000      0.000000
# 25%        7.000000        3.000000       4.000000      5.000000
# 50%        9.000000        4.000000       5.000000      7.000000
# 75%       14.000000        7.000000       8.000000     10.000000
# max    86529.000000     4480.000000   82346.000000   9901.000000
#
#        Q9E_humble_hnst  Q10E_hnstly_ask  Q11E_leader_clean  \
# count     61966.000000     61966.000000       61966.000000
# mean         14.756899        30.931624          10.600846
# std         213.934323       852.002350          51.653479
# min       -3574.000000        -8.000000       -3554.000000
# 25%           6.000000         9.000000           5.000000
# 50%           9.000000        13.000000           7.000000
# 75%          13.000000        20.000000          10.000000
# max       40985.000000    119251.000000        6254.000000
#
#        Q12E_trust_trouble  Q13E_ppl_criminal  Q14E_ppl_brave  Q15E_abu_good  \
# count        61966.000000       61966.000000    61966.000000   61966.000000
# mean            14.692493          16.435836        7.961511       9.120760
# std           1022.569251         311.689030      271.511248      69.535122
# min              0.000000         -40.000000        0.000000       0.000000
# 25%              5.000000           6.000000        3.000000       4.000000
# 50%              7.000000           9.000000        4.000000       6.000000
# 75%             10.000000          13.000000        6.000000       8.000000
# max         254156.000000       47758.000000    62220.000000    9006.000000
#
#        Q16E_ppl_good  Q17E_ppl_notbad  Q18E_komsu_better  Q19E_anrocksa_ok  \
# count   61966.000000     61966.000000       61966.000000      61966.000000
# mean        9.495110        14.067908          13.694365         23.398799
# std        76.840133       113.633664         423.117517       2200.206047
# min         0.000000         0.000000         -12.000000          0.000000
# 25%         4.000000         6.000000           5.000000          6.000000
# 50%         6.000000         8.000000           7.000000          8.000000
# 75%         8.000000        12.000000          10.000000         12.000000
# max      7989.000000     13439.000000       95517.000000     542805.000000
#
#        Q20E_money_good
# count     61966.000000
# mean         27.596311
# std        3012.357722
# min          -9.000000
# 25%           8.000000
# 50%          11.000000
# 75%          15.000000
# max      749602.000000

# %%
df_QE.describe().loc['mean'].plot(kind='line')

# %%
df_QE.describe().loc['mean'][df_QE.describe().loc['mean'] > 25]
# Out:
# Q10E_hnstly_ask    29.360191
# Q20E_money_good    25.535367
# Name: mean, dtype: float64

# %%
df_QE.describe().loc['min'].plot(kind='line')

# %%
df_QE.describe().loc['min'][df_QE.describe().loc['min'] < -1000]
# Out:
# Q9E_humble_hnst     -3574.0
# Q11E_leader_clean   -3554.0
# Name: min, dtype: float64

# %%
df_QE[df_QE['Q11E_leader_clean']  < -2000]
# Out:
#        Q1E_notell_2u  Q2E_ppl_nd_dangun  Q3E_do_moral  Q4E_ppl_good  \
# 17674            1.0               18.0           9.0          14.0
#
#        Q5E_ppl_bad  Q6E_hnsty_best  Q7E_lying_bad  Q8E_ppl_lazy  \
# 17674         53.0            32.0           13.0         103.0
#
#        Q9E_humble_hnst  Q10E_hnstly_ask  Q11E_leader_clean  \
# 17674             15.0            122.0            -3554.0
#
#        Q12E_trust_trouble  Q13E_ppl_criminal  Q14E_ppl_brave  Q15E_abu_good  \
# 17674                21.0               13.0             7.0           14.0
#
#        Q16E_ppl_good  Q17E_ppl_notbad  Q18E_komsu_better  Q19E_anrocksa_ok  \
# 17674           12.0             39.0                1.0               9.0
#
#        Q20E_money_good
# 17674             45.0

# %%
df_QE[df_QE['Q9E_humble_hnst']  < -2000]
# Out:
#        Q1E_notell_2u  Q2E_ppl_nd_dangun  Q3E_do_moral  Q4E_ppl_good  \
# 20722           13.0               17.0           9.0          29.0
#
#        Q5E_ppl_bad  Q6E_hnsty_best  Q7E_lying_bad  Q8E_ppl_lazy  \
# 20722          9.0             5.0            9.0          10.0
#
#        Q9E_humble_hnst  Q10E_hnstly_ask  Q11E_leader_clean  \
# 20722          -3574.0             24.0                8.0
#
#        Q12E_trust_trouble  Q13E_ppl_criminal  Q14E_ppl_brave  Q15E_abu_good  \
# 20722                16.0               37.0            21.0           10.0
#
#        Q16E_ppl_good  Q17E_ppl_notbad  Q18E_komsu_better  Q19E_anrocksa_ok  \
# 20722           19.0             15.0               27.0              29.0
#
#        Q20E_money_good
# 20722             22.0

# %%
df.iloc[17674]['voted']
# Out:
# 'No'

# %%
df.iloc[20722]['voted']
# Out:
# 'No'

# %%
df_QE.describe().loc['max'].plot(kind='line')

# %%
df_QE.describe().loc['max'][df_QE.describe().loc['max'] > 600000]
# Out:
# Q20E_money_good    749602.0
# Name: max, dtype: float64

# %%
df_QE[df_QE['Q20E_money_good'] > 60000]
# Out:
#        Q1E_notell_2u  Q2E_ppl_nd_dangun  Q3E_do_moral  Q4E_ppl_good  \
# 70225            6.0                5.0           5.0           3.0
#
#        Q5E_ppl_bad  Q6E_hnsty_best  Q7E_lying_bad  Q8E_ppl_lazy  \
# 70225         10.0             3.0            3.0           7.0
#
#        Q9E_humble_hnst  Q10E_hnstly_ask  Q11E_leader_clean  \
# 70225              7.0              8.0               11.0
#
#        Q12E_trust_trouble  Q13E_ppl_criminal  Q14E_ppl_brave  Q15E_abu_good  \
# 70225                 6.0                6.0             2.0            5.0
#
#        Q16E_ppl_good  Q17E_ppl_notbad  Q18E_komsu_better  Q19E_anrocksa_ok  \
# 70225            7.0              7.0                5.0               7.0
#
#        Q20E_money_good
# 70225         749602.0

# %%
df.iloc[70225]
# Out:
# Q1_TP_notell_2u                    2
# Q1I                               14
# Q1E_notell_2u                      6
# Q2_TP_ppl_nd_dangun                2
# Q2I                               18
#                            ...
# major                  Liberal Arts
# score                             53
# v_score                           24
# t_score                           24
# m_score                            5
# Name: 70225, Length: 109, dtype: object

# %%
df.iloc[70225]['voted']
# Out:
# 'Yes'

# %%
plt.figure(figsize=(20, 6))
plt.suptitle('마키아벨리즘 질문지별 답변시간', fontsize=16)

plt.subplot(131)
df_QE.describe().loc['mean'].plot(kind='line')
plt.gca().set_title('mean')

plt.subplot(132)
df_QE.describe().loc['min'].plot(kind='line')
plt.gca().set_title('min')

# plt.subplot(333)
# df_QE.describe().loc['25%'].plot(kind='line')
# plt.gca().set_title('25%')

# plt.subplot(334)
# df_QE.describe().loc['50%'].plot(kind='line')
# plt.gca().set_title('50%')

# plt.subplot(335)
# df_QE.describe().loc['75%'].plot(kind='line')
# plt.gca().set_title('75%')

plt.subplot(133)
df_QE.describe().loc['max'].plot(kind='line')
plt.gca().set_title('max');

# %% [markdown]
# ### TYP

# %%
col_list = list(df.columns)
typ_col = []

for col in col_list:
    if "TYP" in col:
        typ_col.append(col)
print(typ_col)
# Out:
# ['TYP_out', 'TYP_fight', 'TYP_depnd', 'TYP_anx', 'TYP_try', 'TYP_quiet', 'TYP_warm', 'TYP_disorg', 'TYP_calm', 'TYP_stable']

# %%
figure, ((ax1,ax2,ax3,ax4,ax5), (ax6,ax7,ax8,ax9,ax10)) = plt.subplots(nrows=2, ncols=5)
figure.set_size_inches(20,10)

for n, c in enumerate(typ_col):
    ax = globals()["ax" + '{}'.format(n+1)]
    plt.figure(figsize=(4, 4))
    
    plt_ = sns.histplot(df, x=c, hue='voted', binwidth=2, ax=ax)
    plt_.set(ylabel="", ylim=(0, 25000))

# %% [markdown]
# ### VCL

# %%
v_cols = []
for i in df.columns:
    if  ("VCL" in i ) | ('voted' in i ):
        v_cols.append(i)
v_cols
# Out:
# ['VCL1',
#  'VCL2',
#  'VCL3',
#  'VCL4',
#  'VCL5',
#  'VCL6_F',
#  'VCL7',
#  'VCL8',
#  'VCL9_F',
#  'VCL10',
#  'VCL11',
#  'VCL12_F',
#  'VCL13',
#  'VCL14',
#  'VCL15',
#  'VCL16',
#  'voted']

# %%
df_vcl = df[v_cols]
df_vcl
# Out:
#          VCL1    VCL2    VCL3    VCL4  VCL5  VCL6_F    VCL7    VCL8  VCL9_F  \
# 0        know    know  n_know    know  know  n_know  n_know    know  n_know
# 1        know    know    know    know  know  n_know  n_know    know  n_know
# 3        know    know    know    know  know  n_know  n_know    know  n_know
# 4        know  n_know  n_know    know  know  n_know  n_know  n_know  n_know
# 6        know    know  n_know    know  know  n_know  n_know  n_know  n_know
# ...       ...     ...     ...     ...   ...     ...     ...     ...     ...
# 73484    know  n_know  n_know    know  know  n_know  n_know  n_know  n_know
# 73485    know  n_know  n_know    know  know  n_know  n_know    know  n_know
# 73486    know    know    know    know  know  n_know    know  n_know  n_know
# 73487  n_know  n_know  n_know  n_know  know  n_know  n_know  n_know  n_know
# 73488    know    know  n_know    know  know  n_know  n_know  n_know  n_know
#
#       VCL10   VCL11 VCL12_F   VCL13   VCL14 VCL15 VCL16 voted
# 0      know    know    know    know    know  know  know   Yes
# 1      know  n_know  n_know    know    know  know  know    No
# 3      know  n_know    know  n_know    know  know  know   Yes
# 4      know  n_know  n_know  n_know  n_know  know  know   Yes
# 6      know  n_know  n_know    know    know  know  know   Yes
# ...     ...     ...     ...     ...     ...   ...   ...   ...
# 73484  know  n_know  n_know  n_know  n_know  know  know    No
# 73485  know  n_know  n_know  n_know  n_know  know  know    No
# 73486  know  n_know  n_know    know    know  know  know    No
# 73487  know  n_know  n_know  n_know    know  know  know   Yes
# 73488  know  n_know  n_know  n_know    know  know  know    No
#
# [61968 rows x 17 columns]

# %%
df_vcl.columns
# Out:
# Index(['VCL1', 'VCL2', 'VCL3', 'VCL4', 'VCL5', 'VCL6_F', 'VCL7', 'VCL8',
#        'VCL9_F', 'VCL10', 'VCL11', 'VCL12_F', 'VCL13', 'VCL14', 'VCL15',
#        'VCL16', 'voted'],
#       dtype='object')

# %%
label = ["know", "n_know"]
index=np.arange(len(label))

plt.figure(figsize=(20, 20))
for i in range(16):
    plt.subplot(4, 4, i+1)
    plot1 = sns.histplot(x=df_vcl[df_vcl.columns[i]], hue=df_vcl['voted'])
    plot1.set(ylabel="", ylim=(0, 33000))
    plt.xticks(index, label)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['education'], hue=df['voted']);

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['urban'], hue=df['voted']);

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['gender'], hue=df['voted']);

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['engnat'], hue=df['voted']);

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x=df['age'], hue=df['voted']);

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['hand'], hue=df['voted']);

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x=df['religion'], hue=df['voted']);

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['orientation'], hue=df['voted']);

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['race'], hue=df['voted']);

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['married'], hue=df['voted']);

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x=df['familysize'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
majors = df['major'].str.lower()
majors = majors.str.strip()
majors.value_counts()
# Out:
# psychology                                3367
# business                                  1988
# engineering                               1734
# english                                   1501
# computer science                          1435
#                                           ...
# politic scienze                              1
# chinese language & literature program;       1
# radio television film                        1
# training/education                           1
# journalism and mass media studies            1
# Name: major, Length: 6380, dtype: int64

# %% [markdown]
# ### COUNTRY

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['country'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
df_cou = df['country'].value_counts()
cou_up100 = df_con[df_con > 100].index

# %%
cou_up100
# Out:
# Index(['US', 'GB', 'CA', 'AU', 'IN', 'HU', 'DE', 'NONE', 'CN', 'NL', 'SE',
#        'PH', 'PL', 'FR', 'ZA', 'ID', 'NO', 'RO', 'VN', 'MY', 'SG', 'IT', 'BR',
#        'NZ', 'FI', 'MX', 'IE', 'ES', 'TR', 'GR', 'BE', 'PT', 'DK', 'AT', 'BG',
#        'RS', 'CH', 'HR', 'RU', 'CZ', 'AE', 'KE', 'HK', 'JP', 'TW', 'SI', 'IL',
#        'PK', 'TH', 'SK', 'AR'],
#       dtype='object')

# %%
idx_list = []
for idx, x in enumerate(df['country']):
    if x in cou_up100 :
        idx_list.append(idx)
len(idx_list)
# Out:
# 59457

# %%
df_cou_100 = df.iloc[idx_list]
df_cou_100
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  3.0   6.0           21.0                  3.0   7.0
# 1                  5.0  17.0            4.0                  5.0   9.0
# 3                  2.0  12.0            9.0                  4.0   1.0
# 4                  5.0  13.0            9.0                  5.0   7.0
# 6                  3.0  11.0            4.0                  3.0  10.0
# ...                ...   ...            ...                  ...   ...
# 73484              2.0  17.0           10.0                  1.0   6.0
# 73485              5.0   9.0            6.0                  5.0   4.0
# 73486              2.0  17.0            5.0                  1.0  18.0
# 73487              4.0  15.0            8.0                  3.0   9.0
# 73488              3.0  12.0            8.0                  1.0  10.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# 0                   19.0             5.0  20.0          15.0             2.0
# 1                    8.0             1.0  16.0           6.0             3.0
# 3                   10.0             2.0   7.0          10.0             1.0
# 4                    5.0             2.0  19.0           9.0             1.0
# 6                    4.0             2.0  17.0           5.0             4.0
# ...                  ...             ...   ...           ...             ...
# 73484               14.0             2.0  16.0          25.0             4.0
# 73485                4.0             1.0  15.0           7.0             1.0
# 73486                7.0             1.0   9.0           5.0             1.0
# 73487                8.0             5.0  17.0           9.0             3.0
# 73488                6.0             5.0  13.0          37.0             1.0
#
#        ...   orientation   race  voted             married  familysize  \
# 0      ...  Heterosexual  Black    Yes   Currently married           5
# 1      ...  Heterosexual  White     No       Never married           2
# 3      ...  Heterosexual  White    Yes  Previously married           2
# 4      ...    Homosexual  White    Yes       Never married           2
# 6      ...  Heterosexual  White    Yes       Never married           2
# ...    ...           ...    ...    ...                 ...         ...
# 73484  ...  Heterosexual  Asian     No   Currently married           1
# 73485  ...    Homosexual  White     No       Never married           2
# 73486  ...  Heterosexual  White     No       Never married           3
# 73487  ...  Heterosexual  Asian    Yes       Never married           4
# 73488  ...  Heterosexual  Other     No       Never married           4
#
#                          major  score  v_score  t_score  m_score
# 0                   Marketing    75.0     35.0     33.0      7.0
# 1                  mathematics   91.0     37.0     45.0      9.0
# 3      international relations   78.0     37.0     36.0      5.0
# 4                   Management   85.0     35.0     41.0      9.0
# 6                          NaN   66.0     28.0     31.0      7.0
# ...                        ...    ...      ...      ...      ...
# 73484                 business   59.0     28.0     26.0      5.0
# 73485                sociology   90.0     37.0     43.0     10.0
# 73486                      NaN   69.0     34.0     27.0      8.0
# 73487                 Business   53.0     25.0     22.0      6.0
# 73488                      NaN   64.0     36.0     23.0      5.0
#
# [59457 rows x 109 columns]

# %%
plt.figure(figsize=(20, 6))
sns.countplot(x=df_cou_100['country'], hue=df_cou_100['voted']);

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['screenw'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
sw = df['screenw'].value_counts() 
sw[sw > 1000]
# Out:
# 360.0     13289
# 1366.0    10276
# 375.0      8947
# 1920.0     7784
# 1280.0     5245
# 320.0      4064
# 1440.0     3932
# 414.0      3330
# 1536.0     2930
# 412.0      2625
# 768.0      2589
# 1600.0     1652
# 1680.0     1077
# Name: screenw, dtype: int64

# %%
# 1위 모바일 기기, 2위 패드, 3위 모바일, 4위, 5위 데스크탑

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['screenh'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
sh = df['screenh'].value_counts() 
sh[sh>1000]
# Out:
# 640.0     11306
# 768.0     11052
# 667.0      7951
# 1080.0     7327
# 900.0      5445
# 1024.0     3651
# 736.0      3139
# 568.0      2966
# 864.0      2922
# 800.0      2693
# 720.0      2026
# 732.0      1274
# 740.0      1160
# 846.0      1100
# 1050.0     1085
# 812.0      1003
# Name: screenh, dtype: int64

# %%
# 1위, 2위, 3위 모바일, 4위 데스크탑, 5위 패드

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['introelapse'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
df['introelapse'].describe()
# Out:
# count    7.348600e+04
# mean     1.204275e+03
# std      4.713113e+04
# min      0.000000e+00
# 25%      4.000000e+00
# 50%      1.100000e+01
# 75%      3.400000e+01
# max      7.783236e+06
# Name: introelapse, dtype: float64

# %%
df['introelapse'].mean()
# Out:
# 1204.2753177475981

# %%
df['introelapse'].median()
# Out:
# 11.0

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['testelapse'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
df['testelapse'].mean(), df['testelapse'].median()
# Out:
# (1089.4802139182973, 179.0)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df['surveyelapse'], hue=df['voted'])
plt.legend(loc='upper center');

# %%
df['surveyelapse'].mean(), df['surveyelapse'].median()
# Out:
# (2982.841853882894, 186.0)
