# %%
df = pd.read_csv('../MACH_data/cut_off_by_avg.csv')
df
# Out:
#        Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun   Q2I  \
# 0                  5.0  17.0            4.0                  5.0   9.0
# 1                  5.0  16.0            4.0                  5.0  12.0
# 2                  2.0  12.0            9.0                  4.0   1.0
# 3                  5.0  13.0            9.0                  5.0   7.0
# 4                  4.0   4.0            9.0                  3.0   5.0
# ...                ...   ...            ...                  ...   ...
# 53015              4.0  15.0            5.0                  1.0  16.0
# 53016              5.0   1.0           10.0                  5.0  13.0
# 53017              2.0  17.0           10.0                  1.0   6.0
# 53018              5.0   9.0            6.0                  5.0   4.0
# 53019              2.0  17.0            5.0                  1.0  18.0
#
#        Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  Q4_VN_ppl_good  \
# ...

# %%
cols = []
for col in df.columns:
    if ("TYP" in col) | ("VCL" in col) | ("screen" in col) | ("lapse" in col):
        cols.append(col)
cols
# Out:
# ['introelapse',
#  'testelapse',
#  'surveyelapse',
#  'TYP_out',
#  'TYP_fight',
#  'TYP_depnd',
#  'TYP_anx',
#  'TYP_try',
#  'TYP_quiet',
#  'TYP_warm',
#  'TYP_disorg',
#  'TYP_calm',
#  'TYP_stable',
#  'VCL1',
#  'VCL2',
#  'VCL3',
#  'VCL4',
#  'VCL5',
#  'VCL6_F',
#  'VCL7',
#  'VCL8',
#  'VCL9_F',
#  'VCL10',
#  'VCL11',
#  'VCL12_F',
#  'VCL13',
#  'VCL14',
#  'VCL15',
#  'VCL16',
#  'screenw',
#  'screenh']

# %%
df_tve = df[cols]
df_tve
# Out:
#        introelapse  testelapse  surveyelapse  TYP_out  TYP_fight  TYP_depnd  \
# 0             38.0       143.0           150        2          5          6
# 1              4.0       143.0           157        1          7          6
# 2             60.0       191.0           269        6          5          5
# 3             37.0       302.0           334        2          5          5
# 4              3.0       244.0           158        2          4          6
# ...            ...         ...           ...      ...        ...        ...
# 53015          9.0       151.0           157        7          7          7
# 53016          5.0       237.0           220        7          7          3
# 53017          6.0       494.0           340        6          4          5
# 53018          6.0       295.0           140        5          7          5
# 53019         11.0       111.0           122        1          6          1
#
# ...

# %%
from py
