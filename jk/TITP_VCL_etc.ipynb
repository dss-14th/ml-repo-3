# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#TYP,-VCL,-etc-컬럼들-세부확인" data-toc-modified-id="TYP,-VCL,-etc-컬럼들-세부확인-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>TYP, VCL, etc 컬럼들 세부확인</a></span><ul class="toc-item"><li><span><a href="#TITIP,-VCL,-etc-컬럼들-선별" data-toc-modified-id="TITIP,-VCL,-etc-컬럼들-선별-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>TITIP, VCL, etc 컬럼들 선별</a></span></li><li><span><a href="#Auto-ML-이용해-feature-importance-확인" data-toc-modified-id="Auto-ML-이용해-feature-importance-확인-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Auto ML 이용해 feature importance 확인</a></span><ul class="toc-item"><li><span><a href="#베스트-모델-확인" data-toc-modified-id="베스트-모델-확인-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>베스트 모델 확인</a></span></li><li><span><a href="#model-:-GBC" data-toc-modified-id="model-:-GBC-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>model : GBC</a></span><ul class="toc-item"><li><span><a href="#feature-:-TYP_disorg_1" data-toc-modified-id="feature-:-TYP_disorg_1-1.2.2.1"><span class="toc-item-num">1.2.2.1&nbsp;&nbsp;</span>feature : TYP_disorg_1</a></span></li><li><span><a href="#feature-:-VCL3_know" data-toc-modified-id="feature-:-VCL3_know-1.2.2.2"><span class="toc-item-num">1.2.2.2&nbsp;&nbsp;</span>feature : VCL3_know</a></span></li><li><span><a href="#feature-:-screenh" data-toc-modified-id="feature-:-screenh-1.2.2.3"><span class="toc-item-num">1.2.2.3&nbsp;&nbsp;</span>feature : screenh</a></span></li><li><span><a href="#feature-:-introelapse" data-toc-modified-id="feature-:-introelapse-1.2.2.4"><span class="toc-item-num">1.2.2.4&nbsp;&nbsp;</span>feature : introelapse</a></span></li><li><span><a href="#feature-:-TYP_quiet_1" data-toc-modified-id="feature-:-TYP_quiet_1-1.2.2.5"><span class="toc-item-num">1.2.2.5&nbsp;&nbsp;</span>feature : TYP_quiet_1</a></span></li></ul></li><li><span><a href="#model-:-lightgbm" data-toc-modified-id="model-:-lightgbm-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>model : lightgbm</a></span><ul class="toc-item"><li><span><a href="#feature-:-surveyelapse" data-toc-modified-id="feature-:-surveyelapse-1.2.3.1"><span class="toc-item-num">1.2.3.1&nbsp;&nbsp;</span>feature : surveyelapse</a></span></li><li><span><a href="#feature-:-testelapse" data-toc-modified-id="feature-:-testelapse-1.2.3.2"><span class="toc-item-num">1.2.3.2&nbsp;&nbsp;</span>feature : testelapse</a></span></li><li><span><a href="#feature-:-introelapse" data-toc-modified-id="feature-:-introelapse-1.2.3.3"><span class="toc-item-num">1.2.3.3&nbsp;&nbsp;</span>feature : introelapse</a></span></li></ul></li></ul></li><li><span><a href="#TITP-&amp;-voted" data-toc-modified-id="TITP-&amp;-voted-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>TITP &amp; voted</a></span></li><li><span><a href="#VCL-&amp;-voted" data-toc-modified-id="VCL-&amp;-voted-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>VCL &amp; voted</a></span></li><li><span><a href="#etc-&amp;-voted" data-toc-modified-id="etc-&amp;-voted-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>etc &amp; voted</a></span></li></ul></li></ul></div>

# %% [markdown]
# # TYP, VCL, etc 컬럼들 세부확인

# %%
df = pd.read_csv('../MACH_data/cut_off_by_avg_over_18age.csv', )
df
# Out:
#        Unnamed: 0  Q1_TP_notell_2u   Q1I  Q1E_notell_2u  Q2_TP_ppl_nd_dangun  \
# 0               0              5.0  17.0            4.0                  5.0
# 1               2              2.0  12.0            9.0                  4.0
# 2               3              5.0  13.0            9.0                  5.0
# 3               5              3.0  11.0            4.0                  3.0
# 4               6              4.0   6.0           11.0                  4.0
# ...           ...              ...   ...            ...                  ...
# 44562       53015              4.0  15.0            5.0                  1.0
# 44563       53016              5.0   1.0           10.0                  5.0
# 44564       53017              2.0  17.0           10.0                  1.0
# 44565       53018              5.0   9.0            6.0                  5.0
# 44566       53019              2.0  17.0            5.0                  1.0
#
#         Q2I  Q2E_ppl_nd_dangun  Q3_TN_do_moral   Q3I  Q3E_do_moral  ...  \
# 0       9.0                8.0             1.0  16.0           6.0  ...
# 1       1.0               10.0             2.0   7.0          10.0  ...
# 2       7.0                5.0             2.0  19.0           9.0  ...
# 3      10.0                4.0             2.0  17.0           5.0  ...
# 4      15.0                4.0             3.0   2.0          11.0  ...
# ...     ...                ...             ...   ...           ...  ...
# 44562  16.0                5.0             1.0  10.0           5.0  ...
# 44563  13.0                5.0             4.0  15.0          11.0  ...
# 44564   6.0               14.0             2.0  16.0          25.0  ...
# 44565   4.0                4.0             1.0  15.0           7.0  ...
# 44566  18.0                7.0             1.0   9.0           5.0  ...
#
#                     religion   orientation   race  voted             married  \
# 0                   Agnostic  Heterosexual  White     No       Never married
# 1      Christian(Protestant)  Heterosexual  White    Yes  Previously married
# 2        Christian(Catholic)    Homosexual  White    Yes       Never married
# 3                    Atheist  Heterosexual  White    Yes       Never married
# 4                   Agnostic  Heterosexual  Asian     No       Never married
# ...                      ...           ...    ...    ...                 ...
# 44562               Agnostic    Homosexual  White    Yes       Never married
# 44563                  Other  Heterosexual  Asian     No       Never married
# 44564                  Other  Heterosexual  Asian     No   Currently married
# 44565                Atheist    Homosexual  White     No       Never married
# 44566               Agnostic  Heterosexual  White     No       Never married
#
#        familysize  score  v_score  t_score  m_score
# 0               2   91.0     37.0     45.0      9.0
# 1               2   78.0     37.0     36.0      5.0
# 2               2   85.0     35.0     41.0      9.0
# 3               2   66.0     28.0     31.0      7.0
# 4               1   77.0     35.0     35.0      7.0
# ...           ...    ...      ...      ...      ...
# 44562           3   83.0     42.0     34.0      7.0
# 44563           1   64.0     31.0     26.0      7.0
# 44564           1   59.0     28.0     26.0      5.0
# 44565           2   90.0     37.0     43.0     10.0
# 44566           3   69.0     34.0     27.0      8.0
#
# [44567 rows x 109 columns]

# %% [markdown]
# ## TITIP, VCL, etc 컬럼들 선별

# %%
cols = []
for col in df.columns:
    if ("TYP" in col) | ("VCL" in col) | ("screen" in col) | ("lapse" in col) | ("voted" in col):
        cols.append(col)
cols
# Out:
# ['introelapse',
#  'testelapse',
#  'surveyelapse',
#  'TYP_out',
#  'TYP_fight',
#  'TYP_depnd',
#  'TYP_anx',
#  'TYP_try',
#  'TYP_quiet',
#  'TYP_warm',
#  'TYP_disorg',
#  'TYP_calm',
#  'TYP_stable',
#  'VCL1',
#  'VCL2',
#  'VCL3',
#  'VCL4',
#  'VCL5',
#  'VCL6_F',
#  'VCL7',
#  'VCL8',
#  'VCL9_F',
#  'VCL10',
#  'VCL11',
#  'VCL12_F',
#  'VCL13',
#  'VCL14',
#  'VCL15',
#  'VCL16',
#  'screenw',
#  'screenh',
#  'voted']

# %%
df_tve = df[cols]
df_tve
# Out:
#        introelapse  testelapse  surveyelapse  TYP_out  TYP_fight  TYP_depnd  \
# 0             38.0       143.0           150        2          5          6
# 1             60.0       191.0           269        6          5          5
# 2             37.0       302.0           334        2          5          5
# 3              2.0        73.0           119        6          7          7
# 4             40.0       185.0           361        3          5          6
# ...            ...         ...           ...      ...        ...        ...
# 44562          9.0       151.0           157        7          7          7
# 44563          5.0       237.0           220        7          7          3
# 44564          6.0       494.0           340        6          4          5
# 44565          6.0       295.0           140        5          7          5
# 44566         11.0       111.0           122        1          6          1
#
#        TYP_anx  TYP_try  TYP_quiet  TYP_warm  ...  VCL10   VCL11  VCL12_F  \
# 0            2        4          6         5  ...   know  n_know   n_know
# 1            7        7          2         6  ...   know  n_know     know
# 2            6        7          6         5  ...   know  n_know   n_know
# 3            2        6          4         7  ...   know  n_know   n_know
# 4            2        6          7         5  ...   know  n_know   n_know
# ...        ...      ...        ...       ...  ...    ...     ...      ...
# 44562        5        7          6         2  ...   know  n_know   n_know
# 44563        4        6          6         4  ...   know  n_know   n_know
# 44564        2        6          6         6  ...   know  n_know   n_know
# 44565        5        5          6         3  ...   know  n_know   n_know
# 44566        5        5          6         3  ...   know  n_know   n_know
#
#         VCL13   VCL14   VCL15 VCL16 screenw screenh voted
# 0        know    know    know  know  1536.0   864.0    No
# 1      n_know    know    know  know  1280.0   720.0   Yes
# 2      n_know  n_know    know  know   360.0   640.0   Yes
# 3        know    know    know  know   360.0   640.0   Yes
# 4        know    know    know  know  1680.0   945.0    No
# ...       ...     ...     ...   ...     ...     ...   ...
# 44562  n_know    know  n_know  know   375.0   812.0   Yes
# 44563  n_know  n_know  n_know  know   375.0   667.0    No
# 44564  n_know  n_know    know  know  2048.0  1080.0    No
# 44565  n_know  n_know    know  know  1440.0   900.0    No
# 44566    know    know    know  know  1280.0  1024.0    No
#
# [44567 rows x 32 columns]

# %%
df_tve.columns
# Out:
# Index(['introelapse', 'testelapse', 'surveyelapse', 'TYP_out', 'TYP_fight',
#        'TYP_depnd', 'TYP_anx', 'TYP_try', 'TYP_quiet', 'TYP_warm',
#        'TYP_disorg', 'TYP_calm', 'TYP_stable', 'VCL1', 'VCL2', 'VCL3', 'VCL4',
#        'VCL5', 'VCL6_F', 'VCL7', 'VCL8', 'VCL9_F', 'VCL10', 'VCL11', 'VCL12_F',
#        'VCL13', 'VCL14', 'VCL15', 'VCL16', 'screenw', 'screenh', 'voted'],
#       dtype='object')

# %%
sns.heatmap(df_tve.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Auto ML 이용해 feature importance 확인

# %%
from pycaret.classification import *

# %%
clf = setup(data=df_tve, target='voted', normalize=True, normalize_method='minmax')
# Out:
# <style  type="text/css" >
# #T_b307976c_1d9b_11eb_a8bc_acde48001122row29_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_b307976c_1d9b_11eb_a8bc_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row0_col1" class="data row0 col1" >7404</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row1_col1" class="data row1 col1" >voted</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row4_col1" class="data row4 col1" >(44567, 32)</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row6_col1" class="data row6 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row7_col1" class="data row7 col1" >26</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row11_col1" class="data row11 col1" >(31196, 91)</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row12_col1" class="data row12 col1" >(13371, 91)</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_b307976c_1d9b_11eb_a8bc_acde48001122level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48001122row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_b307976c_1d9b_11eb_a8bc_acde48

# %% [markdown]
# ### 베스트 모델 확인

# %%
models = compare_models(exclude=['catboost'], sort='AUC')
# Out:
# <style  type="text/css" >
#     #T_8e84ec7c_1d9c_11eb_a8bc_acde48001122 th {
#           text-align: left;
#     }#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col7,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col0,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col7,#T_8e84ec7c_1d9c_1 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col2,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col1,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col3,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col4,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col5,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col6,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row1_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row2_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row3_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row4_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row6_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row7_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row8_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row9_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row10_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row11_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row12_col8,#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row5_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_8e84ec7c_1d9c_11eb_a8bc_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8e84ec7c_1d9c_11eb_a8bc_acde48001122level0_row0" class="row_heading level0 row0" >lr</th>
#                         <td id="T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col0" class="data row0 col0" >Logistic Regression</td>
#                         <td id="T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col1" class="data row0 col1" >0.5682</td>
#                         <td id="T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col2" class="data row0 col2" >0.5892</td>
#                         <td id="T_8e84ec7c_1d9c_11eb_a8bc_acde48001122row0_col3" class="d

# %% [markdown]
# ### model : GBC

# %%
gbc = create_model('gbc')
# Out:
# <style  type="text/css" >
# #T_8fa55f32_1d9d_11eb_a8bc_acde48001122row10_col0,#T_8fa55f32_1d9d_11eb_a8bc_acde48001122row10_col1,#T_8fa55f32_1d9d_11eb_a8bc_acde48001122row10_col2,#T_8fa55f32_1d9d_11eb_a8bc_acde48001122row10_col3,#T_8fa55f32_1d9d_11eb_a8bc_acde48001122row10_col4,#T_8fa55f32_1d9d_11eb_a8bc_acde48001122row10_col5,#T_8fa55f32_1d9d_11eb_a8bc_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row0_col0" class="data row0 col0" >0.5740</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row0_col1" class="data row0 col1" >0.5886</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row0_col2" class="data row0 col2" >0.5662</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row0_col3" class="data row0 col3" >0.5723</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row0_col4" class="data row0 col4" >0.5655</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row0_col5" class="data row0 col5" >0.1342</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row0_col6" class="data row0 col6" >0.1379</td>
#             </tr>
#             <tr>
#                         <th id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row1_col0" class="data row1 col0" >0.5792</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row1_col1" class="data row1 col1" >0.5953</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row1_col2" class="data row1 col2" >0.5717</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row1_col3" class="data row1 col3" >0.5776</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row1_col4" class="data row1 col4" >0.5715</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row1_col5" class="data row1 col5" >0.1452</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row1_col6" class="data row1 col6" >0.1488</td>
#             </tr>
#             <tr>
#                         <th id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row2_col0" class="data row2 col0" >0.5728</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row2_col1" class="data row2 col1" >0.5915</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row2_col2" class="data row2 col2" >0.5650</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row2_col3" class="data row2 col3" >0.5709</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row2_col4" class="data row2 col4" >0.5642</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row2_col5" class="data row2 col5" >0.1316</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row2_col6" class="data row2 col6" >0.1353</td>
#             </tr>
#             <tr>
#                         <th id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row3_col0" class="data row3 col0" >0.5625</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row3_col1" class="data row3 col1" >0.5846</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row3_col2" class="data row3 col2" >0.5547</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row3_col3" class="data row3 col3" >0.5599</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row3_col4" class="data row3 col4" >0.5539</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row3_col5" class="data row3 col5" >0.1108</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row3_col6" class="data row3 col6" >0.1139</td>
#             </tr>
#             <tr>
#                         <th id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row4_col0" class="data row4 col0" >0.5599</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row4_col1" class="data row4 col1" >0.5831</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row4_col2" class="data row4 col2" >0.5521</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row4_col3" class="data row4 col3" >0.5572</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row4_col4" class="data row4 col4" >0.5512</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row4_col5" class="data row4 col5" >0.1056</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row4_col6" class="data row4 col6" >0.1085</td>
#             </tr>
#             <tr>
#                         <th id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row5_col0" class="data row5 col0" >0.5542</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row5_col1" class="data row5 col1" >0.5815</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row5_col2" class="data row5 col2" >0.5468</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row5_col3" class="data row5 col3" >0.5511</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row5_col4" class="data row5 col4" >0.5465</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row5_col5" class="data row5 col5" >0.0948</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row5_col6" class="data row5 col6" >0.0970</td>
#             </tr>
#             <tr>
#                         <th id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row6_col0" class="data row6 col0" >0.5697</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row6_col1" class="data row6 col1" >0.5872</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row6_col2" class="data row6 col2" >0.5624</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row6_col3" class="data row6 col3" >0.5676</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row6_col4" class="data row6 col4" >0.5621</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row6_col5" class="data row6 col5" >0.1263</td>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row6_col6" class="data row6 col6" >0.1293</td>
#             </tr>
#             <tr>
#                         <th id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8fa55f32_1d9d_11eb_a8bc_acde48001122row7_co

# %%
gbc_df = pull()

# %%
gbc_feature = plot_model(gbc, plot='feature')
gbc_feature

# %% [markdown]
# #### feature : TYP_disorg_1

# %%
df_tve['TYP_disorg'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_tve['TYP_disorg'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
sns.countplot(x=df_tve['TYP_disorg'], hue=df_tve['voted']);

# %% [markdown]
# #### feature : VCL3_know

# %%
sns.countplot(x=df_tve['VCL3'], hue=df_tve['voted']);

# %% [markdown]
# #### feature : screenh

# %%
df_tve['screenh'].value_counts()
# Out:
# 640.0     6745
# 768.0     5880
# 1080.0    5166
# 667.0     4580
# 900.0     3442
#           ...
# 537.0        1
# 1184.0       1
# 1132.0       1
# 721.0        1
# 240.0        1
# Name: screenh, Length: 367, dtype: int64

# %%
sns.countplot(x=df_tve['screenh'], hue=df_tve['voted']);

# %% [markdown]
# #### feature : introelapse

# %%
df_tve['introelapse'].value_counts()
# Out:
# 3.0         4331
# 4.0         3802
# 2.0         2770
# 5.0         2632
# 6.0         2047
#             ...
# 411.0          1
# 490.0          1
# 378642.0       1
# 3215.0         1
# 1808.0         1
# Name: introelapse, Length: 2052, dtype: int64

# %%
sns.countplot(x=df_tve['introelapse'], hue=df_tve['voted']);

# %%
df_tve['introelapse'].min(), df_tve['introelapse'].max()
# Out:
# (0.0, 7783236.0)

# %%
samples = df_tve['introelapse'].values
q1 = np.percentile(samples, 25)
q2 = np.median(samples)
q3 = np.percentile(samples, 75)
iqr = q3 - q1

upper_fence = q3 + iqr*2.0
lower_fence = q1 - iqr*2.0
print("upper : {}\nlower : {}".format(upper_fence, lower_fence))
# Out:
# upper : 94.0
# lower : -56.0

# %%
def iqr_2(serise):
    samples = df_tve['introelapse'].values
    q1 = np.percentile(samples, 25)
    q2 = np.median(samples)
    q3 = np.percentile(samples, 75)
    iqr = q3 - q1

    upper_fence = q3 + iqr*2.0
    lower_fence = q1 - iqr*2.0
    return ("upper : {}, lower : {}".format(upper_fence, lower_fence))

# %%
iqr_2(df_tve['introelapse'])
# Out:
# 'upper : 94.0, lower : -56.0'

# %%
len(df_tve[df_tve['introelapse'] > 94])
# Out:
# 5138

# %%
df_tve_i = df_tve[df_tve['introelapse'] < 94]
df_tve_i
# Out:
#        introelapse  testelapse  surveyelapse  TYP_out  TYP_fight  TYP_depnd  \
# 0             38.0       143.0           150        2          5          6
# 1             60.0       191.0           269        6          5          5
# 2             37.0       302.0           334        2          5          5
# 3              2.0        73.0           119        6          7          7
# 4             40.0       185.0           361        3          5          6
# ...            ...         ...           ...      ...        ...        ...
# 44562          9.0       151.0           157        7          7          7
# 44563          5.0       237.0           220        7          7          3
# 44564          6.0       494.0           340        6          4          5
# 44565          6.0       295.0           140        5          7          5
# 44566         11.0       111.0           122        1          6          1
#
#        TYP_anx  TYP_try  TYP_quiet  TYP_warm  ...  VCL10   VCL11  VCL12_F  \
# 0            2        4          6         5  ...   know  n_know   n_know
# 1            7        7          2         6  ...   know  n_know     know
# 2            6        7          6         5  ...   know  n_know   n_know
# 3            2        6          4         7  ...   know  n_know   n_know
# 4            2        6          7         5  ...   know  n_know   n_know
# ...        ...      ...        ...       ...  ...    ...     ...      ...
# 44562        5        7          6         2  ...   know  n_know   n_know
# 44563        4        6          6         4  ...   know  n_know   n_know
# 44564        2        6          6         6  ...   know  n_know   n_know
# 44565        5        5          6         3  ...   know  n_know   n_know
# 44566        5        5          6         3  ...   know  n_know   n_know
#
#         VCL13   VCL14   VCL15 VCL16 screenw screenh voted
# 0        know    know    know  know  1536.0   864.0    No
# 1      n_know    know    know  know  1280.0   720.0   Yes
# 2      n_know  n_know    know  know   360.0   640.0   Yes
# 3        know    know    know  know   360.0   640.0   Yes
# 4        know    know    know  know  1680.0   945.0    No
# ...       ...     ...     ...   ...     ...     ...   ...
# 44562  n_know    know  n_know  know   375.0   812.0   Yes
# 44563  n_know  n_know  n_know  know   375.0   667.0    No
# 44564  n_know  n_know    know  know  2048.0  1080.0    No
# 44565  n_know  n_know    know  know  1440.0   900.0    No
# 44566    know    know    know  know  1280.0  1024.0    No
#
# [39393 rows x 32 columns]

# %%
df_tve_i['introelapse'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### feature : TYP_quiet_1

# %%
sns.countplot(x=df_tve['TYP_quiet'], hue=df_tve['voted']);

# %% [markdown]
# ### model : lightgbm

# %%
lgbm = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_840d2f3c_1d9e_11eb_a8bc_acde48001122row10_col0,#T_840d2f3c_1d9e_11eb_a8bc_acde48001122row10_col1,#T_840d2f3c_1d9e_11eb_a8bc_acde48001122row10_col2,#T_840d2f3c_1d9e_11eb_a8bc_acde48001122row10_col3,#T_840d2f3c_1d9e_11eb_a8bc_acde48001122row10_col4,#T_840d2f3c_1d9e_11eb_a8bc_acde48001122row10_col5,#T_840d2f3c_1d9e_11eb_a8bc_acde48001122row10_col6{
#             background:  yellow;
#         }</style><table id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row0_col0" class="data row0 col0" >0.5526</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row0_col1" class="data row0 col1" >0.5772</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row0_col2" class="data row0 col2" >0.5451</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row0_col3" class="data row0 col3" >0.5493</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row0_col4" class="data row0 col4" >0.5446</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row0_col5" class="data row0 col5" >0.0913</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row0_col6" class="data row0 col6" >0.0935</td>
#             </tr>
#             <tr>
#                         <th id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row1_col0" class="data row1 col0" >0.5699</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row1_col1" class="data row1 col1" >0.5858</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row1_col2" class="data row1 col2" >0.5627</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row1_col3" class="data row1 col3" >0.5677</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row1_col4" class="data row1 col4" >0.5628</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row1_col5" class="data row1 col5" >0.1269</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row1_col6" class="data row1 col6" >0.1297</td>
#             </tr>
#             <tr>
#                         <th id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row2_col0" class="data row2 col0" >0.5631</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row2_col1" class="data row2 col1" >0.5824</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row2_col2" class="data row2 col2" >0.5553</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row2_col3" class="data row2 col3" >0.5606</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row2_col4" class="data row2 col4" >0.5545</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row2_col5" class="data row2 col5" >0.1121</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row2_col6" class="data row2 col6" >0.1152</td>
#             </tr>
#             <tr>
#                         <th id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row3_col0" class="data row3 col0" >0.5635</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row3_col1" class="data row3 col1" >0.5777</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row3_col2" class="data row3 col2" >0.5562</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row3_col3" class="data row3 col3" >0.5609</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row3_col4" class="data row3 col4" >0.5561</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row3_col5" class="data row3 col5" >0.1138</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row3_col6" class="data row3 col6" >0.1164</td>
#             </tr>
#             <tr>
#                         <th id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row4_col0" class="data row4 col0" >0.5628</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row4_col1" class="data row4 col1" >0.5790</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row4_col2" class="data row4 col2" >0.5550</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row4_col3" class="data row4 col3" >0.5603</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row4_col4" class="data row4 col4" >0.5541</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row4_col5" class="data row4 col5" >0.1114</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row4_col6" class="data row4 col6" >0.1145</td>
#             </tr>
#             <tr>
#                         <th id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row5_col0" class="data row5 col0" >0.5638</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row5_col1" class="data row5 col1" >0.5753</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row5_col2" class="data row5 col2" >0.5567</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row5_col3" class="data row5 col3" >0.5612</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row5_col4" class="data row5 col4" >0.5568</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row5_col5" class="data row5 col5" >0.1147</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row5_col6" class="data row5 col6" >0.1172</td>
#             </tr>
#             <tr>
#                         <th id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row6_col0" class="data row6 col0" >0.5543</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row6_col1" class="data row6 col1" >0.5782</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row6_col2" class="data row6 col2" >0.5475</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row6_col3" class="data row6 col3" >0.5513</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row6_col4" class="data row6 col4" >0.5475</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row6_col5" class="data row6 col5" >0.0960</td>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row6_col6" class="data row6 col6" >0.0979</td>
#             </tr>
#             <tr>
#                         <th id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_840d2f3c_1d9e_11eb_a8bc_acde48001122row7_co

# %%
lgbm_df = pull()

# %%
plot_model(lgbm, plot='feature')

# %% [markdown]
# #### feature : surveyelapse

# %%
df_tve['surveyelapse'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_tve['surveyelapse'].value_counts()
# Out:
# 162      323
# 158      316
# 151      315
# 163      315
# 161      312
#         ...
# 22331      1
# 1457       1
# 1361       1
# 1233       1
# 64         1
# Name: surveyelapse, Length: 1604, dtype: int64

# %%
df_tve['surveyelapse'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df_tve.sort_values(by='surveyelapse', ascending=False)
# Out:
#        introelapse  testelapse  surveyelapse  TYP_out  TYP_fight  TYP_depnd  \
# 21788         12.0       357.0      28122672        7          5          7
# 32537         35.0       394.0      14306052        6          7          6
# 39035         10.0       135.0       5293189        6          1          7
# 22876          2.0       134.0       4752873        7          7          7
# 20253         79.0       195.0       4053838        1          1          6
# ...            ...         ...           ...      ...        ...        ...
# 10965         18.0       476.0             3        5          5          4
# 28735          4.0      2260.0             2        2          5          7
# 28244          8.0       956.0             2        7          2          1
# 11447       1225.0        28.0             2        6          7          5
# 31206       2780.0       857.0             2        7          5          6
#
#        TYP_anx  TYP_try  TYP_quiet  TYP_warm  ...   VCL10   VCL11  VCL12_F  \
# 21788        1        7          1         6  ...    know  n_know   n_know
# 32537        1        6          3         6  ...    know  n_know   n_know
# 39035        6        7          1         7  ...    know  n_know   n_know
# 22876        6        7          7         5  ...    know  n_know   n_know
# 20253        3        6          7         6  ...    know  n_know   n_know
# ...        ...      ...        ...       ...  ...     ...     ...      ...
# 10965        6        5          6         6  ...    know  n_know   n_know
# 28735        1        5          7         2  ...    know  n_know   n_know
# 28244        7        6          1         7  ...    know  n_know   n_know
# 11447        5        6          1         6  ...  n_know  n_know   n_know
# 31206        4        6          7         5  ...  n_know  n_know   n_know
#
#         VCL13   VCL14   VCL15   VCL16 screenw screenh voted
# 21788    know    know    know    know   375.0   667.0   Yes
# 32537  n_know    know    know    know   360.0   640.0    No
# 39035  n_know    know    know    know   375.0   667.0   Yes
# 22876  n_know    know    know    know  1280.0   800.0    No
# 20253  n_know    know    know    know   320.0   568.0    No
# ...       ...     ...     ...     ...     ...     ...   ...
# 10965    know    know    know    know   486.0   863.0   Yes
# 28735    know    know    know    know   834.0  1112.0    No
# 28244    know    know    know    know   375.0   667.0   Yes
# 11447  n_know  n_know  n_know  n_know  1024.0   768.0   Yes
# 31206  n_know  n_know  n_know    know   360.0   640.0    No
#
# [44567 rows x 32 columns]

# %%
df_tve['surveyelapse'].describe()
# Out:
# count    4.456700e+04
# mean     2.571469e+03
# std      1.591806e+05
# min      2.000000e+00
# 25%      1.470000e+02
# 50%      1.860000e+02
# 75%      2.500000e+02
# max      2.812267e+07
# Name: surveyelapse, dtype: float64

# %%
sns.countplot(x=df_tve['surveyelapse'], hue=df_tve['voted']);

# %%
df_tve['surveyelapse'].max()
# Out:
# 28122672

# %%
round(0.05, 0)
# Out:
# 0.0

# %%
df_tve_1 = df_tve[['surveyelapse', 'voted']]

# %%
df_tve_1
# Out:
#        surveyelapse voted
# 0               150    No
# 1               269   Yes
# 2               334   Yes
# 3               119   Yes
# 4               361    No
# ...             ...   ...
# 44562           157   Yes
# 44563           220    No
# 44564           340    No
# 44565           140    No
# 44566           122    No
#
# [44567 rows x 2 columns]

# %%
sns.displot(data=df_tve_1[:100], x='surveyelapse', hue='voted')

# %%
df_tve['surveyelapse'].value_counts()
# Out:
# 162      323
# 158      316
# 151      315
# 163      315
# 161      312
#         ...
# 22331      1
# 1457       1
# 1361       1
# 1233       1
# 64         1
# Name: surveyelapse, Length: 1604, dtype: int64

# %%
df_tve['surveyelapse'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### feature : testelapse

# %% [markdown]
# #### feature : introelapse

# %% [markdown]
# ## TITP & voted

# %% [markdown]
# ## VCL & voted

# %% [markdown]
# ## etc & voted
